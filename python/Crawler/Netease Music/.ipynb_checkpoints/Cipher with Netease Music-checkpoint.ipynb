# %% [markdown]
# # Python Cipher

# %% [markdown]
# ## Stand Library

# %% [markdown]
# ### Hashing

# %% [markdown]
# Python’s standard library has you covered in the hashlib module. It includes the FIPS secure hash algorithms SHA1, SHA224, SHA256, SHA384, and SHA512 as well as RSA’s MD5 algorithm.

# %%
import hashlib
md5 = hashlib.md5()
# md5.update('I Love Python')
# Unicode-objects must be encoded before hashing
md5.update(b'I Love Python')
md5.digest()
hashlib.sha256(b'I Love Python').hexdigest()
# Out:
# b'K\xf2\xe0+\nV\xf6\x95\xb1\xd1d`\x85v\x9aJ'
# '28ea18a0df1c8dbec5850c9164da84d27522189bc832703ab39d757d96fb0333'

# %% [markdown]
# ### Key Derivation

# %%
 import binascii
dk = hashlib.pbkdf2_hmac(hash_name='sha256',
    password=b'password', 
    salt=b'salt', 
    iterations=100000)
binascii.hexlify(dk)
# Out:
# b'0394a2ede332c9a13eb82e9b24631604c31df978b4e2f0fbd2c549944f9d79a5'

# %% [markdown]
# ## PyCryptodome

# %% [markdown]
# ### Install

# %%
pip3 install pycryptodome     --index-url http://mirrors.aliyun.com/pypi/simple/ --trusted-host mirrors.aliyun.com #linux
pip3 install pycryptodomex     --index-url http://mirrors.aliyun.com/pypi/simple/ --trusted-host mirrors.aliyun.com #win

# %% [markdown]
# ### DES(Data Encryption Standard)

# %% [markdown]
# key :  it's 8 bytes
# Pad function:  pad any string out with spaces until it's a multiple of 8

# %%
from Cryptodome.Cipher import DES

key = b'abcdefgh'

def pad(text):
    text = text.decode()
    while len(text) % 8 != 0:
        text+= ' '
    return bytes(text,'utf-8')

des = DES.new(key, DES.MODE_ECB)
text = b'I Love Python'
# encrypted_text = des.encrypt(text)
# Data must be aligned to block boundary in ECB mode
padded_text = pad(text)
# b'I Love Python   '
encrypted_text = des.encrypt(padded_text)
encrypted_text
des.decrypt(encrypted_text)
# Out:
# b'y\x9aM\xac\x17Y\x8f\xfc^\xa5p\x14Lq\xb6\x0e'
# b'I Love Python   '

# %% [markdown]
# ### AES(Advanced Encryption Standard)

# %%
from Cryptodome.Cipher import AES
from Cryptodome.Util.Padding import pad
from base64 import b64encode, b64decode

key = '/I02fMuSSvnouuu+/vyyD7NuSEVDB/0gte/z50dM0b4='
data = 'hello world!'

cipher = AES.new(b64decode(key), AES.MODE_CBC, iv=b'0123456789abcdef')
padded_data = pad(data.encode(), cipher.block_size)
print(padded_data)
# b'hello world!\x04\x04\x04\x04'
print(b64encode(padded_data))
# b'aGVsbG8gd29ybGQhBAQEBA=='
ciphertext = cipher.encrypt(padded_data)
print(ciphertext)
# b'\xf0m\n/e"\n\xfe\xd4\xa3\xeaJ2oF\xf8'
print(b64encode(ciphertext))
# b'8G0KL2UiCv7Uo+pKMm9G+A=='
ciphertext = cipher.encrypt(padded_data)
print(b64encode(ciphertext))
# b'tBXcf/Nf6MtxM1ulzNnIlw=='


cipher = AES.new(b64decode(key), AES.MODE_CBC, iv=b'0123456789abcdef')
padded_data = pad(data.encode(), cipher.block_size)
ciphertext = cipher.encrypt(padded_data)
print(b64encode(ciphertext))
# b'8G0KL2UiCv7Uo+pKMm9G+A=='
# Out:
# b'hello world!\x04\x04\x04\x04'
# b'aGVsbG8gd29ybGQhBAQEBA=='
# b'\xf0m\n/e"\n\xfe\xd4\xa3\xeaJ2oF\xf8'
# b'8G0KL2UiCv7Uo+pKMm9G+A=='
# b'tBXcf/Nf6MtxM1ulzNnIlw=='
# b'8G0KL2UiCv7Uo+pKMm9G+A=='

# %% [markdown]
# ### RSA

# %% [markdown]
# If you want to encrypt your data with RSA, then you'll need to either have access to a public / private RSA key pair or you will need to generate your own.
# Ok Let's we will just generate our own.

# %%
from Cryptodome.PublicKey import RSA
code = 'nobodyknows'
key = RSA.generate(2048) # an RSA key of 2048 bits
encrypted_key = key.exportKey(passphrase=code, pkcs=8, 
        protection="scryptAndAES128-CBC")
#  private key.
# which PKCS standard to use and which encryption scheme to use

with open('my_private_rsa_key.bin', 'wb') as f:
        f.write(encrypted_key)
with open('my_rsa_public.pem', 'wb') as f:
        f.write(key.publickey().exportKey())
# Out:
# 1865
# 450

# %% [markdown]
# ### Encrypting a File
# For this example we are going to be using a hybrid encryption method, so we use PKCS1 OAEP, which is Optimal asymmetric encryption padding. This allows us to write a data of an arbitrary length to the file. Then we create our AES cipher, create some data and encrypt the data. This will return the encrypted text and the MAC. Finally we write out the nonce, MAC (or tag) and the encrypted text.

# %%
from Cryptodome.PublicKey import RSA
from Cryptodome.Random import get_random_bytes
from Cryptodome.Cipher import AES, PKCS1_OAEP

with open('encrypted_data.bin', 'wb') as out_file:
    recipient_key = RSA.import_key(open('my_rsa_public.pem').read())
    session_key = get_random_bytes(16)

    cipher_rsa = PKCS1_OAEP.new(recipient_key)
    out_file.write(cipher_rsa.encrypt(session_key))

    cipher_aes = AES.new(session_key, AES.MODE_EAX)
    data = b'blah blah blah Python blah blah'
    ciphertext, tag = cipher_aes.encrypt_and_digest(data)

    out_file.write(cipher_aes.nonce)
    out_file.write(tag)
    out_file.write(ciphertext)
# Out:
# 256
# 16
# 16
# 31

# %% [markdown]
#  ### decrypt data

# %%
from Cryptodome.PublicKey import RSA
from Cryptodome.Cipher import AES, PKCS1_OAEP

code = 'nobodyknows'

with open('encrypted_data.bin', 'rb') as fobj:
    private_key = RSA.import_key(
        open('my_private_rsa_key.bin').read(),
        passphrase=code)

    enc_session_key, nonce, tag, ciphertext = [ fobj.read(x) 
                                                for x in (private_key.size_in_bytes(), 
                                                16, 16, -1) ]

    cipher_rsa = PKCS1_OAEP.new(private_key)
    session_key = cipher_rsa.decrypt(enc_session_key)

    cipher_aes = AES.new(session_key, AES.MODE_EAX, nonce)
    data = cipher_aes.decrypt_and_verify(ciphertext, tag)

print(data)
# Out:
# b'blah blah blah Python blah blah'

# %% [markdown]
# ## Cryptography

# %% [markdown]
# The cryptography package aims to be “cryptography for humans” much like the requests library is “HTTP for Humans”.

# %% [markdown]
# The Fernet module implements an easy-to-use authentication scheme that uses a symmetric encryption algorithm which guarantees that any message you encrypt with it cannot be manipulated or read without the key you define. The Fernet module also supports key rotation via MultiFernet.

# %%
from cryptography.fernet import Fernet
cipher_key = Fernet.generate_key()
cipher_key
cipher = Fernet(cipher_key)
text = b'My super secret message'
encrypted_text = cipher.encrypt(text)
encrypted_text
decrypted_text = cipher.decrypt(encrypted_text)
decrypted_text
# Out:
# b'IIW_KsInMPbTR60cyxD8nza5RKv_noP_3_bUeoyrqYY='
# b'gAAAAABaq148thkx3uK066S-J59eUdIG8UptOUnKAYVvHGpjjszje5WYX64lICXjgHRbalqFs8RU9V_ovABgO4U-9py6qDwHMAp5Qx4SjyIePb-IFZ0I0y8='
# b'My super secret message'

# %% [markdown]
# ## Parse Netease Music

# %% [markdown]
# We want to download comments from this url,but the data was encrypted with some methods, then we want to find the the cipher out
# URL : http://music.163.com/#/song?id=36990266

# %% [markdown]
# First Download Core.js and Simulate the requests using fiddler

# %% [markdown]
# ![](http://oxswstz0r.bkt.clouddn.com/wy001.PNG)
# ![](http://oxswstz0r.bkt.clouddn.com/wy002.PNG)
# ![](http://oxswstz0r.bkt.clouddn.com/wy003.PNG)
# ![](http://oxswstz0r.bkt.clouddn.com/wy004.PNG)

# %% [markdown]
# GOT:

# %%
var bBU3x = window.asrsea(
JSON.stringify(j7c), 
bsL0x(["流泪", "强"]), 
bsL0x(TY1x.md), 
bsL0x(["爱心", "女孩", "惊恐", "大笑"]));
e7d.data = k7d.cC8u({ params: bBU3x.encText, encSecKey: bBU3x.encSecKey })
}
czW5b(Y7R, e7d)
};

# %% [markdown]
# - j7c : { rid: "R_SO_4_36990266", offset: "0", total: "true", limit: "20", csrf_token: "" }
# - bsL0x(["流泪", "强"]) : 010001
# - bsL0x(TY1x.md) : 
# - bsL0x(["爱心", "女孩", "惊恐", "大笑"])) : 0CoJUm6Qyw8W8jud

# %% [markdown]
# ### Code

# %%
import psycopg2

conn = psycopg2.connect(database="demo", user="lysql", password="123456", host="127.0.0.1", port="5432")
try:  
    cursor = conn.cursor()
    transaction = cursor.execute("""CREATE TABLE MUSIC(
    ID  SERIAL PRIMARY KEY NOT NULL,
    TIME  BIGINT NOT NULL,
    CONTENT    TEXT NOT NULL,
    LIKEDCOUNT    INT NOT NULL,
    NICKNAME   TEXT NOT NULL,
    USERID    BIGINT NOT NULL,
    AVATARURL    TEXT NOT NULL,
    AVATARPATH TEXT NOT NULL);
       """)
    print('Successful')
    conn.commit()
except (Exception, psycopg2.DatabaseError) as error:
        print(error)
finally:
        print(conn)
        if conn is not None:
            conn.close()
# Out:
# Successful
# <connection object at 0x05C9D620; dsn: 'user=lysql password=xxx dbname=demo host=127.0.0.1 port=5432', closed: 0>

# %%
import psycopg2
def save_music(data):
    conn = psycopg2.connect(database="demo", user="lysql", password="123456", host="127.0.0.1", port="5432")
    table = "music"
    keys = ', '.join(data.keys())
    values = ', '.join(['%s'] * len(data))
    sql = 'INSERT INTO {table}({keys}) VALUES ({values})'.format(table=table, keys=keys, values=values)
    try:  
        cursor = conn.cursor()
        cursor.execute(sql, tuple(data.values()));
        conn.commit()
        print ("Records created successfully");
    except (Exception, psycopg2.DatabaseError) as error:
            print(error)
    finally:
            if conn is not None:
                conn.close()

# %%
from Cryptodome.Cipher import AES
from Cryptodome import Random
from Cryptodome.Util.Padding import pad
from hashlib import md5
from base64 import b64encode
import requests
from requests import RequestException
import json
import codecs
import time
import os


headers = {
"Accept":"*/*",
"Accept-Encoding":"gzip, deflate",
"Accept-Language":"zh-CN,zh;q=0.9,en;q=0.8",
"Connection":"keep-alive",
"Content-Type":"application/x-www-form-urlencoded",
"Host":"music.163.com",
"Origin":"http://music.163.com",
"Referer":"http://music.163.com/",
"User-Agent":"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36"
}

comment = {
    "rid": "R_SO_4_36990266", 
    "offset": "0",
    "total":"true",
    "limit": "20",
    "csrf_token":""
}

modulus = ''
nonce = '0CoJUm6Qyw8W8jud'
pubKey = '010001'

def AES_encrypt(text, key, iv):
    key = bytes(key,"utf-8")
    text = bytes(text,"utf-8")
    cipher = AES.new(key, AES.MODE_CBC, iv)
    padded_data = pad(text, cipher.block_size)
    ciphertext = cipher.encrypt(padded_data)
    return b64encode(ciphertext)

def RSA_encrypt(text, pubKey, modulus):
    text = text[::-1]
    rs = int(codecs.encode(bytes(text,"utf-8"), 'hex'),16)** int(pubKey, 16) % int(modulus, 16)
    return format(rs, 'x').zfill(256)

def get_params():
    iv = b'0102030405060708'
    text = str(comment)
    encText1= AES_encrypt(text,nonce, iv)
    encText2 = AES_encrypt(encText1.decode(),16 * 'F', iv)
    encSecKey = RSA_encrypt(16 * 'F', pubKey, modulus)
    data = {
        'params': encText2.decode(),
        'encSecKey': encSecKey
    }
    return data
get_params()
# Out:
# {'encSecKey': '',
#  'params': 'ZNF1o/ZNVZXhOZHkz9GyshKLbI7TVHgmeFB5vQqDSALAON2CiXciAMOFpiU3mnXGZ+t9hYE/7h2wmv7oi2NmPBZ3POk1qtRif3ygZU2BQO3U8kFDasyz/Yk9kkb07D70iUc5rbvwAy62oXeLUCh39aniZ0EYkglrb8VTpUOChwSDkOXP49FnFjcwA8hSZtuR'}

# %%
# params = "..."
# encSecKey = ""
# data = {
#      "params": params,
#      "encSecKey":encSecKey,
# }

def get_json(url):
    s = requests.Session()
    data=get_params()
    try:
        r = requests.post(url, headers=headers, data=data,allow_redirects=True)
        if r.status_code == 200:
            return r.json()
        else:
            if response.history:
                #                 for his in r.history:
                #                     print (his.status_code, his.url)
                print("Request was redirected to ", r.url)
                try:
                    rr = requests.post(url, headers=headers, data=data)
                    if rr.status_code == 200:
                        return rr.json()
                    return(rr.status_code)
                except RequestException:
                    return "Redirected, But Some Still thing Wrong!!!"
    except RequestException as e:
        return  None
# json_text = get_json("http://music.163.com/weapi/v1/resource/comments/R_SO_4_36990266?csrf_token=")
# json_text
# Out:
# {'code': 200,
#  'comments': [{'beReplied': [{'content': '嗯！我愿意给你一个机会',
#      'status': 0,
#      'user': {'authStatus': 0,
#       'avatarUrl': 'http://p1.music.126.net/ZmpMFOG_l1aN1sxib-dGPA==/109951163192295665.jpg',
#       'expertTags': None,
#       'experts': None,
#       'locationInfo': None,
#       'nickname': '久伴央央',
#       'remarkName': None,
#       'userId': 107757058,
#       'userType': 0,
#       'vipType': 0}}],
#    'commentId': 1055755389,
#    'content': '小姐姐 不如给我个机会…',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521210314724,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/P5hOm_6uMdkphdEMrAlNkQ==/18521273371874021.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '要稳也干净_',
#     'remarkName': None,
#     'userId': 546821336,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [{'content': '前些天爷爷去世了，好不容易平复下来。刚随机播到这首眼泪忍不住就流了，感觉心里好像有某些地方空了然后又填补了回来，突然心恸的感觉。手指颤抖到几乎打不出字',
#      'status': 0,
#      'user': {'authStatus': 0,
#       'avatarUrl': 'http://p1.music.126.net/AeuoFuKXfIhOT05j8bn9xQ==/18796151278980069.jpg',
#       'expertTags': None,
#       'experts': None,
#       'locationInfo': None,
#       'nickname': '安妮与Tibbers',
#       'remarkName': None,
#       'userId': 79894931,
#       'userType': 0,
#       'vipType': 0}}],
#    'commentId': 1055767961,
#    'content': '加油[强]人之常情，不要太伤心了',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521210141061,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/sQDqklhwnxfQVuVrdj1_og==/19074327718930388.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '学飞镖的男人',
#     'remarkName': None,
#     'userId': 1315678753,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [{'content': '第一次听这首歌的时候，我就决定了，要在我的婚礼上放这首歌，妈的，那个谁，你倒给我个机会呀！！！】',
#      'status': 0,
#      'user': {'authStatus': 0,
#       'avatarUrl': 'http://p1.music.126.net/8jRVDc5BihxFTh2edPMgOw==/6672936070762610.jpg',
#       'expertTags': None,
#       'experts': None,
#       'locationInfo': None,
#       'nickname': '卿本逍遥',
#       'remarkName': None,
#       'userId': 126110522,
#       'userType': 0,
#       'vipType': 0}}],
#    'commentId': 1055736430,
#    'content': '嗯！我愿意给你一个机会',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521209819690,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/ZmpMFOG_l1aN1sxib-dGPA==/109951163192295665.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '久伴央央',
#     'remarkName': None,
#     'userId': 107757058,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 1055740345,
#    'content': '真正的绝望并没有眼泪 而是满脸微笑.',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521209732964,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/ayxtwWgY6Y17LE3nzkPhug==/109951163188164359.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '颜儿bay',
#     'remarkName': None,
#     'userId': 1398104910,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 1055752129,
#    'content': '我需要的  只是顺其自然  ',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521209725572,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/yQYkZn-2iPBs4a6752VwaQ==/19155691579187861.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '夏天的蓝风铃',
#     'remarkName': None,
#     'userId': 454558073,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 1055747177,
#    'content': '我赵四听不懂在唱些啥，但感觉唱得真的不错[大哭][大哭][大哭]',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521209693519,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/5pFcOkTC4PIp0nkikNCGNA==/109951163148299801.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '亚洲舞王尼古拉斯赵四l',
#     'remarkName': None,
#     'userId': 528210155,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 1055742231,
#    'content': '白色情人节占卜',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521209645116,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/bJwbiqfcdGwFrRRICw28dg==/18513576790321340.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '是魏星沉啦',
#     'remarkName': None,
#     'userId': 330217246,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 1055714401,
#    'content': '真好听',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521208605693,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/3nmjm8yw32J73D8Bzc1jZQ==/109951163185066475.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '小甜甜180311',
#     'remarkName': None,
#     'userId': 1396325523,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [{'content': '我为了下这首歌，花了8元，我觉得值',
#      'status': 0,
#      'user': {'authStatus': 0,
#       'avatarUrl': 'http://p1.music.126.net/M8bkO5v9OdNSBYOQ-4_SSw==/18908301462999416.jpg',
#       'expertTags': None,
#       'experts': None,
#       'locationInfo': None,
#       'nickname': '呵呵尼玛爱',
#       'remarkName': None,
#       'userId': 133139896,
#       'userType': 0,
#       'vipType': 0}}],
#    'commentId': 1055738560,
#    'content': '咋不直接12元包月',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521208393005,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/7htnrzpm58iKMdHlVwEljg==/109951163186624441.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': 'Shuo180312',
#     'remarkName': None,
#     'userId': 1397227822,
#     'userType': 0,
#     'vipType': 11}},
#   {'beReplied': [{'content': '刚刚打游戏和一家伙骂上了，他报地址电话和我约架，我不跟他一般见识，不理他了。游戏结束重新开了一局，没想到现在的人火气这么大，又有人骂我，这次我不能忍了，主动约架，把之前那家伙的地址电话报了上去。🌝🌝',
#      'status': 0,
#      'user': {'authStatus': 0,
#       'avatarUrl': 'http://p1.music.126.net/_rbPPUrw_o9GJT54yU5Knw==/109951163157268063.jpg',
#       'expertTags': None,
#       'experts': None,
#       'locationInfo': None,
#       'nickname': '去乻尃蘩',
#       'remarkName': None,
#       'userId': 417375841,
#       'userType': 0,
#       'vipType': 0}}],
#    'commentId': 1055708317,
#    'content': '哈[呆]你好阴',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521208105771,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/MX8fkS6HPj4zt0YmJDWXRA==/109951163141118393.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '琉湘若',
#     'remarkName': None,
#     'userId': 1288535278,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 1055722824,
#    'content': '还有88天就要中考了。我一定要考到绵阳。每天晚上刷题的时候总要单曲重复这首歌。加油！！！',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 1,
#    'time': 1521207923561,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/G96HrPc5IlbnbheookmlLw==/109951163119257427.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '小小強丶',
#     'remarkName': None,
#     'userId': 644943997,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 1055707973,
#    'content': '激情，鬼步舞',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521207501255,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/J0k_D-Bds_DHwaJTABGa7w==/109951163137425786.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '沙漠孤行的yok',
#     'remarkName': None,
#     'userId': 570938012,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 1055713770,
#    'content': '来怀旧了',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521207349382,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/mHxHO98xKO6sXdJXa8XOEA==/19151293532953777.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '不怕老师的许姐',
#     'remarkName': None,
#     'userId': 337499587,
#     'userType': 0,
#     'vipType': 11}},
#   {'beReplied': [],
#    'commentId': 1055669425,
#    'content': '[亲亲][流泪][流泪][钻石][钻石][钻石][钻石][钻石][钻石]',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521206500893,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/aLqTEJY0GfszKjbYkJ33lw==/109951163192154180.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '冰v龙1803',
#     'remarkName': None,
#     'userId': 1400720431,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 1055697630,
#    'content': '[色][色][色][色][色]',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521206481958,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/aLqTEJY0GfszKjbYkJ33lw==/109951163192154180.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '冰v龙1803',
#     'remarkName': None,
#     'userId': 1400720431,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [{'content': 'faded是fade的过去式，过去的过去已经过去了，唯有静观现在的生活，不以物喜，不以己悲。',
#      'status': 0,
#      'user': {'authStatus': 0,
#       'avatarUrl': 'http://p1.music.126.net/whEJmdaTIut5Fx7EZe0BsA==/109951163111348173.jpg',
#       'expertTags': None,
#       'experts': None,
#       'locationInfo': None,
#       'nickname': '我是你生命的浩劫',
#       'remarkName': None,
#       'userId': 62625855,
#       'userType': 0,
#       'vipType': 0}}],
#    'commentId': 1055680181,
#    'content': 'are，，要，笑？',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 0,
#    'time': 1521206396797,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/Nbr1oEKbSm0Yx9YF9hhtig==/109951163172397531.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '卡修斯驾到',
#     'remarkName': None,
#     'userId': 1388033070,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 1055686773,
#    'content': '刚刚打游戏和一家伙骂上了，他报地址电话和我约架，我不跟他一般见识，不理他了。游戏结束重新开了一局，没想到现在的人火气这么大，又有人骂我，这次我不能忍了，主动约架，把之前那家伙的地址电话报了上去。🌝🌝',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 7,
#    'time': 1521206081482,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/_rbPPUrw_o9GJT54yU5Knw==/109951163157268063.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '去乻尃蘩',
#     'remarkName': None,
#     'userId': 417375841,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 1055678617,
#    'content': '一眨眼，aw怎么掉出前4了！',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 1,
#    'time': 1521205128627,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/YAAKiuaho6FVvNdLTeZ4qA==/109951163143709855.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': 'xpmioimqx',
#     'remarkName': None,
#     'userId': 565078299,
#     'userType': 0,
#     'vipType': 10}},
#   {'beReplied': [],
#    'commentId': 1055676583,
#    'content': '别总听这种对耳朵损伤很大的电子音乐了。每天早起来几首悠扬的小曲，然后品味下气势恢宏的交响乐，听听时下流行的歌曲或者充满诗意的民谣，你就会发现……还是特么的电音好听。[奸笑][奸笑]',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 3,
#    'time': 1521205119094,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/HOYbXc3LkNoJYeTD2L7v9A==/109951163174030005.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': 'Alan--_--Walker',
#     'remarkName': None,
#     'userId': 343536637,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [{'content': '俺飞类 俺飞类。。。。',
#      'status': 0,
#      'user': {'authStatus': 0,
#       'avatarUrl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg',
#       'expertTags': None,
#       'experts': None,
#       'locationInfo': None,
#       'nickname': '想小仙女',
#       'remarkName': None,
#       'userId': 411115248,
#       'userType': 0,
#       'vipType': 0}}],
#    'commentId': 1055672655,
#    'content': '[呆][呆][呆][呆]',
#    'isRemoveHotComment': False,
#    'liked': False,
#    'likedCount': 1,
#    'time': 1521204922645,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/jvbKh3FMiCzr230QYcm4xA==/109951163124298513.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '王朝丶陌路人',
#     'remarkName': None,
#     'userId': 621996159,
#     'userType': 0,
#     'vipType': 0}}],
#  'hotComments': [{'beReplied': [],
#    'commentId': 49330372,
#    'content': 'faded是fade的过去式，过去的过去已经过去了，唯有静观现在的生活，不以物喜，不以己悲。',
#    'liked': False,
#    'likedCount': 246087,
#    'time': 1448510639460,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/whEJmdaTIut5Fx7EZe0BsA==/109951163111348173.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '我是你生命的浩劫',
#     'remarkName': None,
#     'userId': 62625855,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 56847301,
#    'content': '这个女声版本的《Faded》最近很火',
#    'liked': False,
#    'likedCount': 194536,
#    'time': 1451185247460,
#    'user': {'authStatus': 1,
#     'avatarUrl': 'http://p1.music.126.net/93GM3dF-epgkpmn7xdjseQ==/109951162797195316.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '网易UFO丁磊',
#     'remarkName': None,
#     'userId': 48353,
#     'userType': 0,
#     'vipType': 11}},
#   {'beReplied': [],
#    'commentId': 135214242,
#    'content': '我弟弟非常非常喜欢这首歌，无论是什么版本都喜欢，他不容易啊，在外打拼，无依无靠的，也不知道他能否吃饱穿暖，我发这个不是为了求赞，只愿弟弟在外一切都好！',
#    'liked': False,
#    'likedCount': 188725,
#    'time': 1459179507401,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/J7AbjYabVpZnCxWKVrxN2Q==/1426066583642298.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '来自春天棚的挖笋少年',
#     'remarkName': None,
#     'userId': 250382435,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 137832909,
#    'content': '这歌真的很适合在车上听，特别是大清早在马路上驰骋，感觉整个世界都是自己的！！但是到了中午就没那么合适了，毕竟自行车在马路中间还是挺碍眼的',
#    'liked': False,
#    'likedCount': 153315,
#    'time': 1459777338743,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/FPCM88mnSQPpb9Gdo8-8PQ==/1375489057109417.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '猪的小粉丝',
#     'remarkName': None,
#     'userId': 80085018,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 56466882,
#    'content': '昨天@ Alan Walker说在中国有一大批粉丝喜欢Faded这首歌喜欢Faded这首歌的MV。就在刚才他赞了我的推文！超级开心！',
#    'liked': False,
#    'likedCount': 94273,
#    'time': 1451057702287,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/bgo2aGVus3GXxubpSRRojA==/109951163190128229.jpg',
#     'expertTags': ['电子', '欧美'],
#     'experts': None,
#     'locationInfo': None,
#     'nickname': 'EmoDio蓝柒',
#     'remarkName': None,
#     'userId': 41360536,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 66408415,
#    'content': '这首歌我已付费购买，永久拥有，本人目前唯一的一次音乐付费，因为挚爱！这首歌将伴随我跑完人生的第一个马拉松42.195km......[爱心]',
#    'liked': False,
#    'likedCount': 93628,
#    'time': 1454150298553,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/xaMkdBStS-XhKAm0ufleBw==/7776845744179755.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': 'Evanescence-Gao',
#     'remarkName': None,
#     'userId': 32726883,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 125319234,
#    'content': '语言会赋予电音灵魂。（唉反正也没人看到）',
#    'liked': False,
#    'likedCount': 74725,
#    'time': 1456901628625,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/wT6s5VrDqyPsDPY0ci340A==/109951163174405373.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '铃鸟',
#     'remarkName': None,
#     'userId': 246603988,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 53952451,
#    'content': '前些天爷爷去世了，好不容易平复下来。刚随机播到这首眼泪忍不住就流了，感觉心里好像有某些地方空了然后又填补了回来，突然心恸的感觉。手指颤抖到几乎打不出字',
#    'liked': False,
#    'likedCount': 67119,
#    'time': 1450176067114,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/AeuoFuKXfIhOT05j8bn9xQ==/18796151278980069.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '安妮与Tibbers',
#     'remarkName': None,
#     'userId': 79894931,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 134423927,
#    'content': '距高考73天 我要拼一次了 为了自己的梦：为了父母的笑颜 为了去俄罗斯看世界杯 为了听一次现场的faded.',
#    'liked': False,
#    'likedCount': 60639,
#    'time': 1459004993765,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/c7rizRmxej78V2dE47bwMA==/109951163132830978.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': 'Cocilia',
#     'remarkName': None,
#     'userId': 132666388,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 122973550,
#    'content': '我为了下这首歌，花了8元，我觉得值',
#    'liked': False,
#    'likedCount': 39755,
#    'time': 1456237952545,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/M8bkO5v9OdNSBYOQ-4_SSw==/18908301462999416.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '呵呵尼玛爱',
#     'remarkName': None,
#     'userId': 133139896,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 140551591,
#    'content': '在fade上有人说这首歌不应该被填词，现在我觉得他错了，就是这完美的女神铸就了这首神曲',
#    'liked': False,
#    'likedCount': 36305,
#    'time': 1460370729185,
#    'user': {'authStatus': 1,
#     'avatarUrl': 'http://p1.music.126.net/0ndPfXAxfJ-wr-ZO14u3Sw==/19032546276948720.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '阿鱼没有鱼尾巴',
#     'remarkName': None,
#     'userId': 88082645,
#     'userType': 4,
#     'vipType': 11}},
#   {'beReplied': [],
#    'commentId': 137519505,
#    'content': '今天是2016年4月3日，一年前我只身一人来到北京追逐自己的梦想，一年后的今天我还是只身一人，还在为自己的梦想努力的奋斗着。现在是晚上23点08分，一个人坐在床上抽着烟听着这首歌，现在很迷茫，也有很大压力，我一直在坚持，因为这是我最初的梦想。不忘初心，方得始终。wait me',
#    'liked': False,
#    'likedCount': 33896,
#    'time': 1459696092741,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/QI7vsyh4fq8kHgnhx9mfJg==/1402976848860165.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': 'Wlinas',
#     'remarkName': None,
#     'userId': 249701253,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 164603888,
#    'content': '不知道有多少人知道，faded的作者Alan Walker 是个出生于1997的年轻人。',
#    'liked': False,
#    'likedCount': 30364,
#    'time': 1465048541441,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '帐号已注销',
#     'remarkName': None,
#     'userId': 97104149,
#     'userType': 0,
#     'vipType': 0}},
#   {'beReplied': [],
#    'commentId': 156504829,
#    'content': '马上和女友相爱1000天了，我是个军人，那时她大二。我们的爱情不被看好，毕竟回汉通婚很难。希望今年我们的勇气能有个结果……吴楠  爱就是我没有你不行，愿一路走来的艰辛与坎坷，最后都化作要结婚的那一刻的感动和激动。',
#    'liked': False,
#    'likedCount': 17608,
#    'time': 1463582596837,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/Vjl6rLy5SvzlH8Bshj6anQ==/1424967079129852.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '褶子多的杨小白',
#     'remarkName': None,
#     'userId': 272782737,
#     'userType': 0,
#     'vipType': 10}},
#   {'beReplied': [],
#    'commentId': 71141422,
#    'content': '我心里默念三句话：1、“又没考上”2、“我的大哥今天去世了”3、“她拒绝了我”。这个世界如此残酷，这个时代一穷二白的年轻人该如何生存？重复此曲，干完鸡汤，我将重新上路，去寻找，幸福，where  are  you now？[流泪]',
#    'liked': False,
#    'likedCount': 17564,
#    'time': 1455624447984,
#    'user': {'authStatus': 0,
#     'avatarUrl': 'http://p1.music.126.net/DCKd0Gf6VAwQcQjDEs_GUw==/3387595326818664.jpg',
#     'expertTags': None,
#     'experts': None,
#     'locationInfo': None,
#     'nickname': '紫乄尘',
#     'remarkName': None,
#     'userId': 62258833,
#     'userType': 0,
#     'vipType': 0}}],
#  'isMusician': False,
#  'more': True,
#  'moreHot': True,
#  'topComments': [],
#  'total': 209453,
#  'userId': -1}

# %%
def save_avatar(url, nickname):
    if not os.path.exists("avatars"):
        os.mkdir("avatars")
    try:
        response = requests.get(url)
        if response.status_code == 200:
            file_path = '{0}/{1}.{2}'.format("avatars", md5(response.content).hexdigest(), 'jpg')
            if not os.path.exists(file_path):
                with open(file_path, 'wb') as f:
                    f.write(response.content)
            else:
                print('Already Downloaded', file_path)
        return file_path
    except requests.ConnectionError:
        print('Failed to Save Image')

# %%
def parse_page(json, page):
    if json:
        comments = json.get('comments') 
        if page==1 and json.get('moreHot'):
            comments = json.get('hotComments') + json.get('comments')
        for comment in comments:
            music = {}
            music['content'] = comment.get('content')
            music['likedCount'] = comment.get('likedCount')
            music['time'] = comment.get('time')
            comment = comment.get('user')
            music['nickname'] = comment.get('nickname')
            music['avatarurl'] = comment.get('avatarUrl')
            file_path = save_avatar(comment.get('avatarUrl'),comment.get('nickname'))
            print(file_path)
            music['avatarpath'] = file_path
            music['userId'] =  comment.get('userId')
            yield music

## TEST
# for result in parse_page(json_text):
#     print(result)
# json_text.get('total')

# %%
for page in range(1,1000):
    try:
        JSON = get_json("http://music.163.com/weapi/v1/resource/comments/R_SO_4_36990266?csrf_token=")
        if JSON.get('more'):
            results = parse_page(JSON, page)
            comment['offset'] = str(page*20-20)
            if comment['total'] != "false" and page>1:
                comment['total'] = "false"
            print("PAGE : ",page)
            for result in results:
                print(result)
                save_music(result)
            time.sleep(5)
    except AttributeError as e:
        print(JSON)
# Out:
# PAGE :  40
# Already Downloaded avatars/e3df0ab991b43354d55c53f213898e26.jpg
# avatars/e3df0ab991b43354d55c53f213898e26.jpg
# {'content': '这是我们学校晚饭的时候放的歌，每每我绕着操场一圈圈跑，超过身边一个个男生的时候，跟着这歌声，觉得自己是个英雄，86天，加油——', 'likedCount': 3, 'time': 1520870493160, 'nickname': '北有寒山52', 'avatarurl': 'http://p1.music.126.net/u8wWO65k1W3LCGWCxV_zdQ==/19211766672389256.jpg', 'avatarpath': 'avatars/e3df0ab991b43354d55c53f213898e26.jpg', 'userId': 549255785}
# Records created successfully
# avatars/d7d290385aa4611fdbebb564d4c7a958.jpg
# {'content': '据说渔夫时常夜半对着江对岸饮酒\n有人听说过他哭不声嘶力竭 微弱却痛彻心扉\n后来他喝醉后提起曾经有个他深爱的女人\n他未保护好 死在那兵荒马乱的年代', 'likedCount': 1, 'time': 1520869943153, 'nickname': '战骨踏为尘', 'avatarurl': 'http://p1.music.126.net/CQ6hkt9xxI60opbBuXTTeg==/109951163051692037.jpg', 'avatarpath': 'avatars/d7d290385aa4611fdbebb564d4c7a958.jpg', 'userId': 347168469}
# Records created successfully
# avatars/dcd6f60f8dbab7a58fb3b5256670decc.jpg
# {'content': '节奏感很好，很让人舒心，仿佛在广阔的草原…运动很适合', 'likedCount': 0, 'time': 1520869570704, 'nickname': '宿迁市盛源贸易15252888333', 'avatarurl': 'http://p1.music.126.net/H_IuNre8UkSb2XP-_tv_hA==/18896206835378250.jpg', 'avatarpath': 'avatars/dcd6f60f8dbab7a58fb3b5256670decc.jpg', 'userId': 633526173}
# Records created successfully
# avatars/699774b9f27a080d9c44c65c634d0715.jpg
# {'content': '喜欢一首曲子，就算是烂大街了也会一如既往的喜欢', 'likedCount': 0, 'time': 1520869406646, 'nickname': '往昔埋葬', 'avatarurl': 'http://p1.music.126.net/rstX9DuwOEXeQeFhlYQcxw==/19146895486169545.jpg', 'avatarpath': 'avatars/699774b9f27a080d9c44c65c634d0715.jpg', 'userId': 276434310}
# Records created successfully
# avatars/57b6de00ab13a884c58a94c11a09c409.jpg
# {'content': '想知道还有多少召唤师在听这首歌', 'likedCount': 2, 'time': 1520869351734, 'nickname': '林俊杰和新地球', 'avatarurl': 'http://p1.music.126.net/_seUfT--Y18ZioQjBMDY-g==/109951163186666979.jpg', 'avatarpath': 'avatars/57b6de00ab13a884c58a94c11a09c409.jpg', 'userId': 537485979}
# Records created successfully
# avatars/7b2ec45dd646fcea4fe860d6f1e5a269.jpg
# {'content': '看到你的评论  现在时间23:31北上的火车上一个马上30而立的迷茫男人。', 'likedCount': 3, 'time': 1520868759497, 'nickname': '王睿2582', 'avatarurl': 'http://p1.music.126.net/0elmOtMPHgzOZhRCsbrmxw==/18563054813586631.jpg', 'avatarpath': 'avatars/7b2ec45dd646fcea4fe860d6f1e5a269.jpg', 'userId': 441735561}
# Records created successfully
# avatars/fb4bef2672570ca599e22008a7e33dc5.jpg
# {'content': '从六年级喜欢这首歌 到现在初二还是一样', 'likedCount': 1, 'time': 1520868059080, 'nickname': '-吴卿卿吖-', 'avatarurl': 'http://p1.music.126.net/Qh0Y1Zt3tBBFPngGEkMXSg==/109951163164044089.jpg', 'avatarpath': 'avatars/fb4bef2672570ca599e22008a7e33dc5.jpg', 'userId': 1334904082}
# Records created successfully
# avatars/baed88c0c433122768fe698ed6e78452.jpg
# {'content': '😭😭😭', 'likedCount': 1, 'time': 1520866593378, 'nickname': '余生你有我iloveyou', 'avatarurl': 'http://p1.music.126.net/O5WCdlR4Gj2HtKrgKsUhhQ==/109951163169309850.jpg', 'avatarpath': 'avatars/baed88c0c433122768fe698ed6e78452.jpg', 'userId': 87318229}
# Records created successfully
# avatars/f24592dde92d4235e12f2e2c870d841d.jpg
# {'content': '对啊，主要就是因为这首Fade。不过说句实话马丁的表演和创作能力比AW高很多[鬼脸]希望小马丁再连贯3年第一，也希望AW继续进步，这样他的能力大家就心服口服啦[开心]', 'likedCount': 1, 'time': 1520866491000, 'nickname': '猫头鹰之城的共和时代', 'avatarurl': 'http://p1.music.126.net/JFSSxcqQ4WHcyqSjbilLXQ==/18719185464697991.jpg', 'avatarpath': 'avatars/f24592dde92d4235e12f2e2c870d841d.jpg', 'userId': 400979280}
# Records created successfully
# avatars/1ce46c06bca04c5d48ff1068787a8a9d.jpg
# {'content': 'aw在中国的名气比其他百大dj高的许多。甚至是马丁', 'likedCount': 1, 'time': 1520866347112, 'nickname': 'sign丶宇', 'avatarurl': 'http://p1.music.126.net/18xwRRru_rLFkv6SC-2Ecg==/18533367999925599.jpg', 'avatarpath': 'avatars/1ce46c06bca04c5d48ff1068787a8a9d.jpg', 'userId': 468400131}
# Records created successfully
# avatars/da21f2bf805417008c53a7b972d1f968.jpg
# {'content': '送给你们一首alan早起制作的音乐。欢迎进来试听。', 'likedCount': 3, 'time': 1520865592594, 'nickname': 'ZYbook', 'avatarurl': 'http://p1.music.126.net/LUJmc2-2GR4mwGDD8vYBWw==/109951163158311489.jpg', 'avatarpath': 'avatars/da21f2bf805417008c53a7b972d1f968.jpg', 'userId': 1362880012}
# Records created successfully
# avatars/00be2fe74f68d4557f4bdb3f433c6679.jpg
# {'content': '好听', 'likedCount': 0, 'time': 1520865267623, 'nickname': '套路浮云', 'avatarurl': 'http://p1.music.126.net/ekPWmoj1MWZaqghg478PiQ==/109951163182021429.jpg', 'avatarpath': 'avatars/00be2fe74f68d4557f4bdb3f433c6679.jpg', 'userId': 1394262744}
# Records created successfully
# avatars/10aa79c665279e7aba510f52f8cc40a4.jpg
# {'content': '听了有上百遍，不会厌倦', 'likedCount': 0, 'time': 1520865245746, 'nickname': '小子想怎么样12', 'avatarurl': 'http://p1.music.126.net/HWP2YpdxLvy9iDUkFWQ5QA==/109951163153188602.jpg', 'avatarpath': 'avatars/10aa79c665279e7aba510f52f8cc40a4.jpg', 'userId': 533397905}
# Records created successfully
# Already Downloaded avatars/f24592dde92d4235e12f2e2c870d841d.jpg
# avatars/f24592dde92d4235e12f2e2c870d841d.jpg
# {'content': '啊，谢了，AW的确有待提高，当然我希望大家像对待其他百大DJ那样对待我的AW[可爱]', 'likedCount': 1, 'time': 1520865239484, 'nickname': '猫头鹰之城的共和时代', 'avatarurl': 'http://p1.music.126.net/JFSSxcqQ4WHcyqSjbilLXQ==/18719185464697991.jpg', 'avatarpath': 'avatars/f24592dde92d4235e12f2e2c870d841d.jpg', 'userId': 400979280}
# Records created successfully
# avatars/2b2920de94a507ca65eddd692a952aa4.jpg
# {'content': '。。。。这是真绝望', 'likedCount': 0, 'time': 1520865162400, 'nickname': '阿嗑阿', 'avatarurl': 'http://p1.music.126.net/zyroruLugZ-kRN4rl9Ht0Q==/18596040162672667.jpg', 'avatarpath': 'avatars/2b2920de94a507ca65eddd692a952aa4.jpg', 'userId': 330410162}
# Records created successfully
# avatars/ebcb6f2e6b3347a65eaaa37a161245f3.jpg
# {'content': '英语老师说这学期要学会唱，，我有点绝望……', 'likedCount': 0, 'time': 1520865090269, 'nickname': '酷爱海边酷爱浪', 'avatarurl': 'http://p1.music.126.net/DPXDc3-zQ0dKFi3ZV9w7cw==/109951163186568528.jpg', 'avatarpath': 'avatars/ebcb6f2e6b3347a65eaaa37a161245f3.jpg', 'userId': 1350535167}
# Records created successfully
# avatars/aea9237fb488990e201bae8f2c6c9f2e.jpg
# {'content': '这艾伦沃克的衣服我买了，穿起来好帅', 'likedCount': 1, 'time': 1520864575083, 'nickname': '炟炟科技', 'avatarurl': 'http://p1.music.126.net/xBU77yjtkWYKFXagKEOCDg==/109951163173676646.jpg', 'avatarpath': 'avatars/aea9237fb488990e201bae8f2c6c9f2e.jpg', 'userId': 1341557179}
# Records created successfully
# avatars/630a19794ec0b8e4ed3fe531f8e3f6fc.jpg
# {'content': '你头像竟然是我的QQ聊天背景[大哭][大哭]', 'likedCount': 0, 'time': 1520864531322, 'nickname': '夏忧_', 'avatarurl': 'http://p1.music.126.net/XKeIqoDYNlTHfwgAt-MtTw==/109951163185263302.jpg', 'avatarpath': 'avatars/630a19794ec0b8e4ed3fe531f8e3f6fc.jpg', 'userId': 1396485164}
# Records created successfully
# avatars/e2e1a318eb75581adc1ec8fa419cd756.jpg
# {'content': '我憔悴不堪……憔悴不堪……', 'likedCount': 0, 'time': 1520863678681, 'nickname': 'gloneni', 'avatarurl': 'http://p1.music.126.net/F7PBYfxCbHV-S4kWE9JEtw==/109951163166487043.jpg', 'avatarpath': 'avatars/e2e1a318eb75581adc1ec8fa419cd756.jpg', 'userId': 490635490}
# Records created successfully
# avatars/68fee4d85ad5e7d8c962c46b389ba5f3.jpg
# {'content': '不知不觉 好久没有听faded 是你把我带进电音圈的', 'likedCount': 4, 'time': 1520863076195, 'nickname': '爱音乐的小谜弟', 'avatarurl': 'http://p1.music.126.net/0hCPzfBzYHxZMaHf-9PsUg==/109951163190831352.jpg', 'avatarpath': 'avatars/68fee4d85ad5e7d8c962c46b389ba5f3.jpg', 'userId': 301624576}
# Records created successfully
# PAGE :  41
# avatars/0506a756086b40bc414b052ac7fe1003.jpg
# {'content': '拉普拉斯的魔女', 'likedCount': 3, 'time': 1520776078216, 'nickname': 'Sho酱的暖暖暖暖', 'avatarurl': 'http://p1.music.126.net/m7q3P-a6Vyg0NcnNjio47A==/19218363741920208.jpg', 'avatarpath': 'avatars/0506a756086b40bc414b052ac7fe1003.jpg', 'userId': 350947986}
# Records created successfully
# avatars/0c648a48e2a4a97083c7feea21601188.jpg
# {'content': '那种绝望孤独感真的只有这首歌能这么透彻了', 'likedCount': 1, 'time': 1520774627748, 'nickname': '一个不动声色的人呀', 'avatarurl': 'http://p1.music.126.net/bYFcNurjJGmJj4Fd46eCbw==/109951163185033337.jpg', 'avatarpath': 'avatars/0c648a48e2a4a97083c7feea21601188.jpg', 'userId': 126665302}
# Records created successfully
# avatars/da7a32b11c59baadb33f5f38ffdcac9c.jpg
# {'content': '切尔诺贝利，永远的遗憾，永远的痛，抢救核电站的苏联红军忠于国家，但国家却辜负了这伟大的军队[哀伤]他们赢得了自己的战争，却输掉了他们的祖国[哀伤]', 'likedCount': 4, 'time': 1520774355441, 'nickname': '镰锤下的余辉', 'avatarurl': 'http://p1.music.126.net/IzYI9nm48zvctsWi-hc--w==/19230458370353518.jpg', 'avatarpath': 'avatars/da7a32b11c59baadb33f5f38ffdcac9c.jpg', 'userId': 324568206}
# Records created successfully
# avatars/c75a607899b3c433989392f7fa99fdb6.jpg
# {'content': '哈哈哈', 'likedCount': 0, 'time': 1520773803315, 'nickname': 'LxH我在这', 'avatarurl': 'http://p1.music.126.net/W-Wvux4DVXGqazEo3nNsPg==/19085322835141589.jpg', 'avatarpath': 'avatars/c75a607899b3c433989392f7fa99fdb6.jpg', 'userId': 517148781}
# Records created successfully
# avatars/ba74aaf0d00b2daa0d12bd4a916b35f5.jpg
# {'content': '过去式，，exm', 'likedCount': 0, 'time': 1520773070705, 'nickname': '无需要太多LDD', 'avatarurl': 'http://p1.music.126.net/BY_NkF4d3Tr_iapfQavIcA==/109951162975289191.jpg', 'avatarpath': 'avatars/ba74aaf0d00b2daa0d12bd4a916b35f5.jpg', 'userId': 275139645}
# Records created successfully
# avatars/ed174d67e9b648b9cfcab0fe8505d461.jpg
# {'content': '加油！', 'likedCount': 0, 'time': 1520772637586, 'nickname': '水文彩', 'avatarurl': 'http://p1.music.126.net/VbLIGv69MS7JNWscoH8anA==/109951163158787740.jpg', 'avatarpath': 'avatars/ed174d67e9b648b9cfcab0fe8505d461.jpg', 'userId': 1316070756}
# Records created successfully
# avatars/404f389304874efff7ba85559de09a53.jpg
# {'content': '最不喜欢tony老师在理发店拿这首歌作为剪发修头的背景音乐了[撇嘴]', 'likedCount': 2, 'time': 1520772447290, 'nickname': '蠢萌的台台', 'avatarurl': 'http://p1.music.126.net/daXpKHJddFqFdIwanNAQBw==/109951163163010358.jpg', 'avatarpath': 'avatars/404f389304874efff7ba85559de09a53.jpg', 'userId': 1329181394}
# Records created successfully
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# {'content': '我弟弟很小就会唱这首歌了  我也是', 'likedCount': 0, 'time': 1520772320534, 'nickname': '火锅oo', 'avatarurl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg', 'avatarpath': 'avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg', 'userId': 1362852779}
# Records created successfully
# avatars/c3df6014e8067b3ae5d71c6392d0b178.jpg
# {'content': '昨天去看了这首歌mv，今天就日推了', 'likedCount': 0, 'time': 1520772316075, 'nickname': 'lalalalalal_洋', 'avatarurl': 'http://p1.music.126.net/C41pjrBiiEJ49sPXVVB9zA==/109951163051086128.jpg', 'avatarpath': 'avatars/c3df6014e8067b3ae5d71c6392d0b178.jpg', 'userId': 285279518}
# Records created successfully
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# {'content': '我是一听这首歌就内个了[呆]', 'likedCount': 0, 'time': 1520772118711, 'nickname': '火锅oo', 'avatarurl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg', 'avatarpath': 'avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg', 'userId': 1362852779}
# Records created successfully
# avatars/d2cddeff3978129fb34d8a3709390d84.jpg
# {'content': '脑补成了fa♂ded[大哭]', 'likedCount': 0, 'time': 1520771968219, 'nickname': 'Eternty1801', 'avatarurl': 'http://p1.music.126.net/aiZ6kv-wx3gp-fPtWi2MQg==/109951163183133755.jpg', 'avatarpath': 'avatars/d2cddeff3978129fb34d8a3709390d84.jpg', 'userId': 1351547286}
# Records created successfully
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# {'content': '只有这个版本才是真正的经典', 'likedCount': 3, 'time': 1520770719493, 'nickname': '穇种', 'avatarurl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg', 'avatarpath': 'avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg', 'userId': 1391084526}
# Records created successfully
# avatars/8800fa87f68c271dd8c78c0f235df723.jpg
# {'content': '艾伦沃克颜值惊人', 'likedCount': 1, 'time': 1520768193551, 'nickname': '识途人', 'avatarurl': 'http://p1.music.126.net/OsWVqHOcIIZxDQ1917F2cg==/109951163172667109.jpg', 'avatarpath': 'avatars/8800fa87f68c271dd8c78c0f235df723.jpg', 'userId': 481480476}
# Records created successfully
# avatars/10733d545b96f3586782de7c3bf7c727.jpg
# {'content': 'emmm', 'likedCount': 1, 'time': 1520764840912, 'nickname': 'Sallies', 'avatarurl': 'http://p1.music.126.net/mxcElN9dEEKcQXMTtt6btQ==/109951163143702886.jpg', 'avatarpath': 'avatars/10733d545b96f3586782de7c3bf7c727.jpg', 'userId': 530294672}
# Records created successfully
# avatars/9b18b2ba9dc31724441b383a3328645f.jpg
# {'content': '还有装逼力', 'likedCount': 1, 'time': 1520763809594, 'nickname': '昵称只支持中英文-', 'avatarurl': 'http://p1.music.126.net/jnOUCitxV-jPg6bMjog-tw==/1408474402689700.jpg', 'avatarpath': 'avatars/9b18b2ba9dc31724441b383a3328645f.jpg', 'userId': 61952415}
# Records created successfully
# avatars/6e7de48064d6daf52fd9a121d41e70b5.jpg
# {'content': '[大笑]', 'likedCount': 1, 'time': 1520762624403, 'nickname': 'Koster-MSER', 'avatarurl': 'http://p1.music.126.net/PflynCNd7c4Wwq94Hq-FPg==/109951163165436894.jpg', 'avatarpath': 'avatars/6e7de48064d6daf52fd9a121d41e70b5.jpg', 'userId': 1320415942}
# Records created successfully
# avatars/561ebd57c33a8b62392ebadb6ed07e5a.jpg
# {'content': '没限制你的复制力[奸笑]', 'likedCount': 13, 'time': 1520762108091, 'nickname': '丷最丷', 'avatarurl': 'http://p1.music.126.net/OAfWvsVzO6KLNGgrtSvY2Q==/18748872278766204.jpg', 'avatarpath': 'avatars/561ebd57c33a8b62392ebadb6ed07e5a.jpg', 'userId': 474727906}
# Records created successfully
# avatars/e552e479d5ef9362f8caa6ee620f5f33.jpg
# {'content': '好久没有认真的淘歌了…', 'likedCount': 2, 'time': 1520761849388, 'nickname': '楽章', 'avatarurl': 'http://p1.music.126.net/kS7KH2dsKzrhDfOOy_Tdxg==/1365593477396508.jpg', 'avatarpath': 'avatars/e552e479d5ef9362f8caa6ee620f5f33.jpg', 'userId': 121096214}
# Records created successfully
# avatars/dbeb605839546f01652df09c0468913d.jpg
# {'content': '第一次用心去听这首歌，激动的赶紧分享给朋友，超级喜欢[憨笑]', 'likedCount': 2, 'time': 1520760713026, 'nickname': '昣心密语', 'avatarurl': 'http://p1.music.126.net/cT8iGePB1uNamR8FuMcL6Q==/109951163153132836.jpg', 'avatarpath': 'avatars/dbeb605839546f01652df09c0468913d.jpg', 'userId': 1376166015}
# Records created successfully
# avatars/c1449edecfa2ad628316b6f45558308b.jpg
# {'content': '小生不才 歌单无人青睐', 'likedCount': 3, 'time': 1520760461333, 'nickname': '孑然浮生z', 'avatarurl': 'http://p1.music.126.net/3LY2da7cr_tzoRZbdAkQ7A==/109951163108263517.jpg', 'avatarpath': 'avatars/c1449edecfa2ad628316b6f45558308b.jpg', 'userId': 477837417}
# Records created successfully
# PAGE :  42
# avatars/b05328f19452565ee0cea13de1e04968.jpg
# {'content': '老总id很皮😂', 'likedCount': 1, 'time': 1520758654736, 'nickname': '宁六吖', 'avatarurl': 'http://p1.music.126.net/BV3wiYDEd7XAVxMK1rrlNQ==/18811544441431295.jpg', 'avatarpath': 'avatars/b05328f19452565ee0cea13de1e04968.jpg', 'userId': 400259208}
# Records created successfully
# avatars/605184f1e5848877ea046db6d5e4d292.jpg
# {'content': '请来拯救我这个穷逼', 'likedCount': 1, 'time': 1520758246644, 'nickname': '张氏夫妇me', 'avatarurl': 'http://p1.music.126.net/9BjAHnnEsKRNiyalAI7HdQ==/19065531626128086.jpg', 'avatarpath': 'avatars/605184f1e5848877ea046db6d5e4d292.jpg', 'userId': 357004602}
# Records created successfully
# avatars/9061c11259d960a41c4030abfce8b373.jpg
# {'content': '只要收藏就可以听了。', 'likedCount': 1, 'time': 1520757174526, 'nickname': '剑魂171223', 'avatarurl': 'http://p1.music.126.net/tgO8O-QQr0QsqKB-Mo1-ZQ==/18789554209245918.jpg', 'avatarpath': 'avatars/9061c11259d960a41c4030abfce8b373.jpg', 'userId': 1312437147}
# Records created successfully
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# {'content': ' nhgjhgju', 'likedCount': 0, 'time': 1520757131281, 'nickname': '感月吟风多少事', 'avatarurl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg', 'avatarpath': 'avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg', 'userId': 1349324723}
# Records created successfully
# avatars/46df7ce8115b60084b4c706a4f3de001.jpg
# {'content': '我爱你', 'likedCount': 2, 'time': 1520757128240, 'nickname': 'Anney不知倦', 'avatarurl': 'http://p1.music.126.net/M259Xy7SwyxDQxcZ4_mHWw==/18601537720716295.jpg', 'avatarpath': 'avatars/46df7ce8115b60084b4c706a4f3de001.jpg', 'userId': 295729607}
# Records created successfully
# avatars/3f3f65b2fb6b1e9d6d937bba4cf3dcf3.jpg
# {'content': '[憨笑]', 'likedCount': 0, 'time': 1520755606059, 'nickname': '不如做个小盆栽', 'avatarurl': 'http://p1.music.126.net/S3ziKfS2Nmwbdwb6AWf_Qg==/109951163185883492.jpg', 'avatarpath': 'avatars/3f3f65b2fb6b1e9d6d937bba4cf3dcf3.jpg', 'userId': 454713459}
# Records created successfully
# Already Downloaded avatars/f832d0ac2cd00590302f0e8bdbcbd7ec.jpg
# avatars/f832d0ac2cd00590302f0e8bdbcbd7ec.jpg
# {'content': '我又来了，请收藏我的歌单，都是抖腿神曲', 'likedCount': 1, 'time': 1520754824542, 'nickname': '丶梓铭', 'avatarurl': 'http://p1.music.126.net/Rtjx3cWKnBqKQ6-boHJQQw==/109951163176242787.jpg', 'avatarpath': 'avatars/f832d0ac2cd00590302f0e8bdbcbd7ec.jpg', 'userId': 1299121574}
# Records created successfully
# avatars/ae389912c3b92ebbf610d3f6c8bd5c0f.jpg
# {'content': '迷失的自我', 'likedCount': 0, 'time': 1520753320398, 'nickname': '伟大领袖窃格瓦拉', 'avatarurl': 'http://p1.music.126.net/Qi1L8R38SaqAII4zhzQ8Vg==/109951163174013234.jpg', 'avatarpath': 'avatars/ae389912c3b92ebbf610d3f6c8bd5c0f.jpg', 'userId': 422296417}
# Records created successfully
# avatars/eb97b530737c5cfdc4f27bddfce42e1c.jpg
# {'content': '你好！路过的陌生人[可爱]🏼 我是一个喜欢在听过的歌下面留下评论的小仙女[亲亲]\U0001f9da如果你看到这个评论 说明我们有共同点与其说共同点还不如说有缘 [爱心]读这段话大概需要十秒，这十秒你是属于我的\U0001f929 我爱你 再见🎈', 'likedCount': 9, 'time': 1520753181891, 'nickname': '--Indulgence', 'avatarurl': 'http://p1.music.126.net/-2ve6E-9Vkdn5vBET4ITGQ==/19107313068047183.jpg', 'avatarpath': 'avatars/eb97b530737c5cfdc4f27bddfce42e1c.jpg', 'userId': 536419484}
# Records created successfully
# Already Downloaded avatars/10733d545b96f3586782de7c3bf7c727.jpg
# avatars/10733d545b96f3586782de7c3bf7c727.jpg
# {'content': '贫穷限制了你的想象力、吸引力、亲和力、战斗力、意志力、购买力、注意力、爆发力、生命力、影响力、持久力、凝聚力、创造力、竞争力、执行力、亲和力、生育力、摩擦力、超能力、自控力、分辨力、男友力、追星力、撩妹力、撩汉力、女友力、回旋力、劳动力、审美力、吸引力、性能力、富有力、地心力', 'likedCount': 9, 'time': 1520751099514, 'nickname': 'Sallies', 'avatarurl': 'http://p1.music.126.net/mxcElN9dEEKcQXMTtt6btQ==/109951163143702886.jpg', 'avatarpath': 'avatars/10733d545b96f3586782de7c3bf7c727.jpg', 'userId': 530294672}
# Records created successfully
# avatars/6ffc025964411008ea6e44fe77f80b1e.jpg
# {'content': '在b站看了德拉科剪辑 用的这首歌做bgm 看得我心疼死我德 他太好了 太可爱了', 'likedCount': 1, 'time': 1520751033578, 'nickname': '披着猹皮的蛇', 'avatarurl': 'http://p1.music.126.net/kwuvk58osqBeYGQFkYdpUw==/19003958974741129.jpg', 'avatarpath': 'avatars/6ffc025964411008ea6e44fe77f80b1e.jpg', 'userId': 342668130}
# Records created successfully
# avatars/a62e54371ce8fb1f89d67bbdbf9156f3.jpg
# {'content': '曾经第一次听这首歌彻夜无眠，不止是因为旋律，更多的是表达出来的内容，致敬自己失去的青春', 'likedCount': 1, 'time': 1520751009145, 'nickname': '四友大叔', 'avatarurl': 'http://p1.music.126.net/2TkwbVA9-md_f69vwNjHhQ==/109951162793231261.jpg', 'avatarpath': 'avatars/a62e54371ce8fb1f89d67bbdbf9156f3.jpg', 'userId': 109385431}
# Records created successfully
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# {'content': '[大哭][大哭][大哭]', 'likedCount': 0, 'time': 1520750744632, 'nickname': '繁叶知秋桔', 'avatarurl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg', 'avatarpath': 'avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg', 'userId': 630114513}
# Records created successfully
# avatars/d8bd95aea8a0bd69c7db94d44a88bb98.jpg
# {'content': '加油，明年的今天我将会是下一个你。', 'likedCount': 3, 'time': 1520750652460, 'nickname': '鬼神龙膽', 'avatarurl': 'http://p1.music.126.net/bajhAad0LAg5FwBiiLp60w==/109951163184409971.jpg', 'avatarpath': 'avatars/d8bd95aea8a0bd69c7db94d44a88bb98.jpg', 'userId': 1395924114}
# Records created successfully
# avatars/a92ec99d4dd83d5b920b655b28cea518.jpg
# {'content': '第一首听的电音，从此一发不可收拾', 'likedCount': 0, 'time': 1520750088034, 'nickname': '顾名思义r', 'avatarurl': 'http://p1.music.126.net/YkdfsKQwlTrU-QyNWXu61A==/109951163184425333.jpg', 'avatarpath': 'avatars/a92ec99d4dd83d5b920b655b28cea518.jpg', 'userId': 1361576832}
# Records created successfully
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# {'content': 'kk', 'likedCount': 0, 'time': 1520749580438, 'nickname': 'dds6268', 'avatarurl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg', 'avatarpath': 'avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg', 'userId': 618045202}
# Records created successfully
# avatars/5dba6ee9f3dc09b5d71b7e167612f610.jpg
# {'content': '如今我要高考了', 'likedCount': 4, 'time': 1520748578876, 'nickname': '簪花挽鬓', 'avatarurl': 'http://p1.music.126.net/5OX62oTxbSTDtvZ2S2QrcQ==/18889609765531750.jpg', 'avatarpath': 'avatars/5dba6ee9f3dc09b5d71b7e167612f610.jpg', 'userId': 132989571}
# Records created successfully
# avatars/2f8ac57716292157bd16194ad2b89e78.jpg
# {'content': '加油', 'likedCount': 0, 'time': 1520748375439, 'nickname': '心事说给影子听du', 'avatarurl': 'http://p1.music.126.net/eOshVfHl3NyXmTXsh1Q2Uw==/18599338697499741.jpg', 'avatarpath': 'avatars/2f8ac57716292157bd16194ad2b89e78.jpg', 'userId': 311797761}
# Records created successfully
# Already Downloaded avatars/2f8ac57716292157bd16194ad2b89e78.jpg
# avatars/2f8ac57716292157bd16194ad2b89e78.jpg
# {'content': '为你祈祷', 'likedCount': 0, 'time': 1520748327409, 'nickname': '心事说给影子听du', 'avatarurl': 'http://p1.music.126.net/eOshVfHl3NyXmTXsh1Q2Uw==/18599338697499741.jpg', 'avatarpath': 'avatars/2f8ac57716292157bd16194ad2b89e78.jpg', 'userId': 311797761}
# Records created successfully
# avatars/e8593157f83fb5a84b9148e51df7e743.jpg
# {'content': '回你的看守所去', 'likedCount': 1, 'time': 1520747548896, 'nickname': '保加利亚比利king', 'avatarurl': 'http://p1.music.126.net/EOHX7mAuS8sRX2Mz5qw9nw==/19150194021453031.jpg', 'avatarpath': 'avatars/e8593157f83fb5a84b9148e51df7e743.jpg', 'userId': 501592534}
# Records created successfully
# PAGE :  43
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# {'content': '兄den一起', 'likedCount': 1, 'time': 1520746927374, 'nickname': '神一铭', 'avatarurl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg', 'avatarpath': 'avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg', 'userId': 1394800505}
# Records created successfully
# avatars/ef642cd8aaac475cf82e8886b544066f.jpg
# {'content': '怎么哪都有你[大哭]', 'likedCount': 3, 'time': 1520746887845, 'nickname': '小小小列', 'avatarurl': 'http://p1.music.126.net/Td1lU-zcyxKNcpONM48kTw==/109951163184622019.jpg', 'avatarpath': 'avatars/ef642cd8aaac475cf82e8886b544066f.jpg', 'userId': 580561295}
# Records created successfully
# avatars/fc39f6d7d60041a39d9d1b1f85618d60.jpg
# {'content': '20w了', 'likedCount': 0, 'time': 1520746873589, 'nickname': '爸气男', 'avatarurl': 'http://p1.music.126.net/1Pjmw6dm71L54IMPUCOkNQ==/18775260558089762.jpg', 'avatarpath': 'avatars/fc39f6d7d60041a39d9d1b1f85618d60.jpg', 'userId': 489594796}
# Records created successfully
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# {'content': '喝酒以后听，，世界都是你的。。', 'likedCount': 2, 'time': 1520746700749, 'nickname': '神一铭', 'avatarurl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg', 'avatarpath': 'avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg', 'userId': 1394800505}
# Records created successfully
# avatars/c38c40077d1195aa6ef155cc48f050ae.jpg
# {'content': '记得昨年刷高考题总是听这歌，旋律一响起就想起那个认真执着的自己。', 'likedCount': 2, 'time': 1520746667761, 'nickname': '森夏无眠', 'avatarurl': 'http://p1.music.126.net/CzsYcm913KSsgqR8ClnA5g==/109951163184640328.jpg', 'avatarpath': 'avatars/c38c40077d1195aa6ef155cc48f050ae.jpg', 'userId': 613616909}
# Records created successfully
# avatars/537bbd4bb6df5221907a102e58dd0ba9.jpg
# {'content': '封面这不是我的背影吗？', 'likedCount': 4, 'time': 1520746442573, 'nickname': '全民偶像周某人', 'avatarurl': 'http://p1.music.126.net/dPalqFINrW8SzvMzhN8Caw==/109951163183550103.jpg', 'avatarpath': 'avatars/537bbd4bb6df5221907a102e58dd0ba9.jpg', 'userId': 320951818}
# Records created successfully
# avatars/4f40de948dbed70d2e30475d9de541f2.jpg
# {'content': '老姐你在哪里啊，只能祝你幸福了', 'likedCount': 3, 'time': 1520745661073, 'nickname': '三花落水波静溢', 'avatarurl': 'http://p1.music.126.net/qpZhQJPi-TszyiLYEEzUBg==/18544363115956851.jpg', 'avatarpath': 'avatars/4f40de948dbed70d2e30475d9de541f2.jpg', 'userId': 471459635}
# Records created successfully
# avatars/733e29e00e3a031d7f04eb7bd3b9d504.jpg
# {'content': '“英语版《faded》\n翻译:又杀了兔卖来、北极飞蛾，俺脑子傻，也废了胃。俺废了艾米杀了谁，问了谁啊？俺来，胃癌有闹，胃癌有闹，胃癌有闹，胃癌有闹，我吃嘞他的范特西，胃癌有闹，喂我们拿紧拿驴。胃癌有闹，俺呆梨，按到了屎，按到了屎 咦？胃癌有闹，俺拿着狙，到晚上完嘞我杀了你，俺飞嘞，俺飞嘞', 'likedCount': 12, 'time': 1520745460610, 'nickname': '算了不改名字了', 'avatarurl': 'http://p1.music.126.net/scuwlG8VM-zDr89b6-C9WQ==/109951163164851201.jpg', 'avatarpath': 'avatars/733e29e00e3a031d7f04eb7bd3b9d504.jpg', 'userId': 278863948}
# Records created successfully
# avatars/b82b23f0778edb577478cdeae4075f1b.jpg
# {'content': '给你凑个整数', 'likedCount': 0, 'time': 1520745439420, 'nickname': '以取茴香1712', 'avatarurl': 'http://p1.music.126.net/UfnOXT69C-5e-qbW1Yx9XQ==/18928092672680540.jpg', 'avatarpath': 'avatars/b82b23f0778edb577478cdeae4075f1b.jpg', 'userId': 1325707897}
# Records created successfully
# avatars/8fdef13407556632cf8283bc1254bcd0.jpg
# {'content': '你去听听就知道了', 'likedCount': 0, 'time': 1520745180830, 'nickname': 'MTLove丶', 'avatarurl': 'http://p1.music.126.net/W94HNS__WCx4l11yOnLtrA==/109951163113369606.jpg', 'avatarpath': 'avatars/8fdef13407556632cf8283bc1254bcd0.jpg', 'userId': 423433078}
# Records created successfully
# avatars/741ddc8f138baeff9230cf7e87b238bb.jpg
# {'content': '有什么不一样吗？', 'likedCount': 0, 'time': 1520744841903, 'nickname': '一川烟雨满城风絮梅子黄时雨', 'avatarurl': 'http://p1.music.126.net/02gxKVTpWkNO6oMhjsOXpQ==/109951163181606267.jpg', 'avatarpath': 'avatars/741ddc8f138baeff9230cf7e87b238bb.jpg', 'userId': 1394137085}
# Records created successfully
# Already Downloaded avatars/8fdef13407556632cf8283bc1254bcd0.jpg
# avatars/8fdef13407556632cf8283bc1254bcd0.jpg
# {'content': '喜欢电音澎湃的听《fade》\n喜欢电音动感&女声附和的听《faded》\n喜欢电音动感的听《faded（instrumental）》\n喜欢电音缓和&女声附和的就听《faded（restrung）》\n喜欢电音怪异的听《fade（mich\xa0remix）》\n喜欢电音寂静的听《fade（two\xa0ways\xa0remix）》\n喜欢电音动感&rap的听《fade（marvin）》', 'likedCount': 4, 'time': 1520744628646, 'nickname': 'MTLove丶', 'avatarurl': 'http://p1.music.126.net/W94HNS__WCx4l11yOnLtrA==/109951163113369606.jpg', 'avatarpath': 'avatars/8fdef13407556632cf8283bc1254bcd0.jpg', 'userId': 423433078}
# Records created successfully
# Already Downloaded avatars/8fdef13407556632cf8283bc1254bcd0.jpg
# avatars/8fdef13407556632cf8283bc1254bcd0.jpg
# {'content': '走啊，一起去找亚特兰蒂斯吧，找到这个海底的世界', 'likedCount': 3, 'time': 1520744578352, 'nickname': 'MTLove丶', 'avatarurl': 'http://p1.music.126.net/W94HNS__WCx4l11yOnLtrA==/109951163113369606.jpg', 'avatarpath': 'avatars/8fdef13407556632cf8283bc1254bcd0.jpg', 'userId': 423433078}
# Records created successfully
# avatars/8555a7dfcffc1d64429ac7068c837ca3.jpg
# {'content': '兄弟，加油，你们可以的', 'likedCount': 1, 'time': 1520743502292, 'nickname': '动听的小调', 'avatarurl': 'http://p1.music.126.net/C3HdJtOuLc39JfeY96M2Eg==/109951163128601234.jpg', 'avatarpath': 'avatars/8555a7dfcffc1d64429ac7068c837ca3.jpg', 'userId': 421358101}
# Records created successfully
# avatars/1e07b52b0234d96f31e3a85ec50bf928.jpg
# {'content': '一直喜欢听', 'likedCount': 1, 'time': 1520743032138, 'nickname': '小小怪部下', 'avatarurl': 'http://p1.music.126.net/i8MByESySQD_BQncdmni7g==/109951163184118281.jpg', 'avatarpath': 'avatars/1e07b52b0234d96f31e3a85ec50bf928.jpg', 'userId': 293808290}
# Records created successfully
# Already Downloaded avatars/1e07b52b0234d96f31e3a85ec50bf928.jpg
# avatars/1e07b52b0234d96f31e3a85ec50bf928.jpg
# {'content': '下午3点补考，稳住我们能过', 'likedCount': 2, 'time': 1520742998298, 'nickname': '小小怪部下', 'avatarurl': 'http://p1.music.126.net/i8MByESySQD_BQncdmni7g==/109951163184118281.jpg', 'avatarpath': 'avatars/1e07b52b0234d96f31e3a85ec50bf928.jpg', 'userId': 293808290}
# Records created successfully
# avatars/91e339a299b5fa5a042140327854b52c.jpg
# {'content': '同道中人抱抱你', 'likedCount': 0, 'time': 1520742531782, 'nickname': 'psychokiller丧', 'avatarurl': 'http://p1.music.126.net/eNmmaMvRAmdXXIpRbbApMQ==/109951163184153191.jpg', 'avatarpath': 'avatars/91e339a299b5fa5a042140327854b52c.jpg', 'userId': 587070222}
# Records created successfully
# avatars/82017994561d926212fa5fbde6a373a8.jpg
# {'content': '胃癌又来', 'likedCount': 2, 'time': 1520741585554, 'nickname': '利希纳', 'avatarurl': 'http://p1.music.126.net/s2x22yeibNmTwIEFHyTVAQ==/109951163156568408.jpg', 'avatarpath': 'avatars/82017994561d926212fa5fbde6a373a8.jpg', 'userId': 1378040586}
# Records created successfully
# avatars/311b0e8838fcd76109ba11c625b8b993.jpg
# {'content': '永夜终至，吾辈铭记，巍巍大任，死亦无终。无享妻爱，不履寸土，决绝子嗣，身归兄弟。何言无冕，兄弟所望，何争俗荣，生死于斯，心念所归，无惧无退。铸兵利剑，暗夜无当；凝聚础石，长城屹立；鸣无尽之号角，警外患之袭扰；锻坚钢之神盾，固王国之永宁。于今挺身，奉以生命，以夜为始，死亦无终。', 'likedCount': 3, 'time': 1520741389156, 'nickname': 'bloodglory', 'avatarurl': 'http://p1.music.126.net/SH6k0RmshYIltKNUt4UApw==/18903903416466704.jpg', 'avatarpath': 'avatars/311b0e8838fcd76109ba11c625b8b993.jpg', 'userId': 341670558}
# Records created successfully
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# {'content': '6666666     fadede@[强][强][强][强][强][强][强]', 'likedCount': 1, 'time': 1520740563932, 'nickname': '权志龙万岁', 'avatarurl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg', 'avatarpath': 'avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg', 'userId': 1307755334}
# Records created successfully
# PAGE :  44
# avatars/61ee06dfe8af16ced4a2a4450bfe9732.jpg
# {'content': '不明白这一个个喷Alan都怎么想的。如果不喜欢，不用告诉别人，我们不想知道，我们只是支持我们爱的音乐，这没有错。你们不喜欢，也不能是没品味，只是大家观点不同。键盘侠不是一个好的“职业”。无脑黑也一样。', 'likedCount': 2, 'time': 1520739419022, 'nickname': '陶志富', 'avatarurl': 'http://p1.music.126.net/zI5YAEzh9CToV92-EMHVzA==/109951163151158336.jpg', 'avatarpath': 'avatars/61ee06dfe8af16ced4a2a4450bfe9732.jpg', 'userId': 1302751580}
# Records created successfully
# avatars/872e91db94300f2d631ce73b466d98bd.jpg
# {'content': '怎么设置不了来电铃声？会的帮忙下', 'likedCount': 0, 'time': 1520739165498, 'nickname': '迪1989', 'avatarurl': 'http://p1.music.126.net/yDQim1zeL95DT_3jjq8ccQ==/109951163184080418.jpg', 'avatarpath': 'avatars/872e91db94300f2d631ce73b466d98bd.jpg', 'userId': 545675508}
# Records created successfully
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# {'content': '是的！', 'likedCount': 0, 'time': 1520739116391, 'nickname': '小白和风', 'avatarurl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg', 'avatarpath': 'avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg', 'userId': 432485498}
# Records created successfully
# avatars/06f0a56f9c6f7dcbb1fd3ed790c81aa8.jpg
# {'content': '这个头像。。', 'likedCount': 0, 'time': 1520738602092, 'nickname': '鸶輞', 'avatarurl': 'http://p1.music.126.net/hCw6E08bhMMPuePI9314yQ==/1420569036675191.jpg', 'avatarpath': 'avatars/06f0a56f9c6f7dcbb1fd3ed790c81aa8.jpg', 'userId': 308984750}
# Records created successfully
# avatars/2070c4cc86a8ed9b82ee6053c3bfc4d7.jpg
# {'content': '好听', 'likedCount': 1, 'time': 1520736457110, 'nickname': '皇上的吧主', 'avatarurl': 'http://p1.music.126.net/Ac-eUHcVEMTIU5Z5pWXQoA==/109951163169814828.jpg', 'avatarpath': 'avatars/2070c4cc86a8ed9b82ee6053c3bfc4d7.jpg', 'userId': 1386439679}
# Records created successfully
# avatars/14b7e02c585b95ee39e3a3973cc12e49.jpg
# {'content': '这首歌每次听到心里都有一种说不出来的感觉，在大脑中环绕', 'likedCount': 2, 'time': 1520736071003, 'nickname': 'ming0911', 'avatarurl': 'http://p1.music.126.net/VMHd5N9LHpfqethToblUHQ==/19112810625704628.jpg', 'avatarpath': 'avatars/14b7e02c585b95ee39e3a3973cc12e49.jpg', 'userId': 291769301}
# Records created successfully
# avatars/2b3828392d9dea839f48b72a2096ce1a.jpg
# {'content': '我可以说来考古吗...', 'likedCount': 1, 'time': 1520735855756, 'nickname': '第1届花样抖腿锦标赛冠军获得者', 'avatarurl': 'http://p1.music.126.net/FF_72KNSRk6I1E9S6Wn28A==/19128203788707002.jpg', 'avatarpath': 'avatars/2b3828392d9dea839f48b72a2096ce1a.jpg', 'userId': 423343264}
# Records created successfully
# avatars/6924f20458a24d17532a60439f12fa12.jpg
# {'content': '大师球～', 'likedCount': 0, 'time': 1520735078219, 'nickname': '_瑟瑟发抖_', 'avatarurl': 'http://p1.music.126.net/4R3STFiRm8_8GZ5T8NWS7A==/109951163169243760.jpg', 'avatarpath': 'avatars/6924f20458a24d17532a60439f12fa12.jpg', 'userId': 608758013}
# Records created successfully
# avatars/594ca43ffe18a953a8a63540349d8bf2.jpg
# {'content': '可能偷吃去了', 'likedCount': 1, 'time': 1520734355899, 'nickname': '布丁狗1711', 'avatarurl': 'http://p1.music.126.net/M06PIgY50JXXXYnWWlp5iA==/18908301463296693.jpg', 'avatarpath': 'avatars/594ca43ffe18a953a8a63540349d8bf2.jpg', 'userId': 637035061}
# Records created successfully
# avatars/a1940368ec5ca2534b51fcb30c888057.jpg
# {'content': '这是几年前的歌了已经忘了那时我几岁了', 'likedCount': 0, 'time': 1520734314159, 'nickname': '梵高的白日梦', 'avatarurl': 'http://p1.music.126.net/Ma4A25qrYgFnXzCqh8bK5Q==/109951163181502439.jpg', 'avatarpath': 'avatars/a1940368ec5ca2534b51fcb30c888057.jpg', 'userId': 344432843}
# Records created successfully
# avatars/d94f092f97bb8b2f2a65be1106678e4c.jpg
# {'content': '请带好耳机，开始享受\n00:00▬▬▬▬▬▬▬▬▬▬◙03：32\n⏮     ⏪     ▶     ⏩     ⏭', 'likedCount': 4, 'time': 1520734031626, 'nickname': '菜菜菜CJY', 'avatarurl': 'http://p1.music.126.net/9J_wxgLbwS--RkBLJDkLgw==/18940187300618025.jpg', 'avatarpath': 'avatars/d94f092f97bb8b2f2a65be1106678e4c.jpg', 'userId': 615980137}
# Records created successfully
# avatars/84dab18c9a6b40e88059796388445ee2.jpg
# {'content': '的确超级烂大街', 'likedCount': 1, 'time': 1520733280537, 'nickname': '局长不乱来', 'avatarurl': 'http://p1.music.126.net/V3MrZ8f7QL4rTb7GDMGBSw==/1369991488702227.jpg', 'avatarpath': 'avatars/84dab18c9a6b40e88059796388445ee2.jpg', 'userId': 445446376}
# Records created successfully
# avatars/c0252fc0841dffcf13e1d07bdc0a8dd2.jpg
# {'content': '⩙ 这符号像不像', 'likedCount': 3, 'time': 1520732703262, 'nickname': 'abdulla134', 'avatarurl': 'http://p1.music.126.net/x9dyhPMUN-pUC-pT1Ltl3A==/3412884099754489.jpg', 'avatarpath': 'avatars/c0252fc0841dffcf13e1d07bdc0a8dd2.jpg', 'userId': 289197880}
# Records created successfully
# avatars/0dc6d3c8f4ff60f5541a0b28bc1f5944.jpg
# {'content': '小女子不才，听到自己喜欢的歌，却不能写出自己喜欢的评论…', 'likedCount': 5, 'time': 1520732447459, 'nickname': '北欧有条小鲸鱼_', 'avatarurl': 'http://p1.music.126.net/5rM33CVlhXGoRwQ1JNsXOw==/109951163183935005.jpg', 'avatarpath': 'avatars/0dc6d3c8f4ff60f5541a0b28bc1f5944.jpg', 'userId': 432924131}
# Records created successfully
# avatars/79edddd9e52a66542bf32452addbf00d.jpg
# {'content': '这首歌是我们最后的记忆了吧', 'likedCount': 3, 'time': 1520732186254, 'nickname': '小信宗', 'avatarurl': 'http://p1.music.126.net/Vs1G3zcQOnJO-VXKtV3Vug==/18546562139041157.jpg', 'avatarpath': 'avatars/79edddd9e52a66542bf32452addbf00d.jpg', 'userId': 399085856}
# Records created successfully
# avatars/d088c8fa319ccab5c645697a530d9d05.jpg
# {'content': '对不起，我应该是想表达烂大街的意思，怪我用词不搭。请原谅', 'likedCount': 0, 'time': 1520731908460, 'nickname': 'Dripiceyeah', 'avatarurl': 'http://p1.music.126.net/DdeU5FzYJGclP_X2oT-wWA==/18531168976728243.jpg', 'avatarpath': 'avatars/d088c8fa319ccab5c645697a530d9d05.jpg', 'userId': 324674313}
# Records created successfully
# avatars/59074559a2a0ed4186cee206f0f4b943.jpg
# {'content': '土嗨不至于吧，就是有点烂大街', 'likedCount': 0, 'time': 1520731325328, 'nickname': 'Zezezeed', 'avatarurl': 'http://p1.music.126.net/HjXjdUtULgs5Tfrv6tJqjw==/109951163189147245.jpg', 'avatarpath': 'avatars/59074559a2a0ed4186cee206f0f4b943.jpg', 'userId': 545786254}
# Records created successfully
# avatars/850e61d076379b9bb664e5fe4ffa3950.jpg
# {'content': '找工作碰壁了！', 'likedCount': 0, 'time': 1520731261699, 'nickname': '郭志生', 'avatarurl': 'http://p1.music.126.net/clI5r1QupWe2IoFbYHhTbQ==/109951162799427388.jpg', 'avatarpath': 'avatars/850e61d076379b9bb664e5fe4ffa3950.jpg', 'userId': 98910770}
# Records created successfully
# avatars/56bc6a7ba8c2cfefdebfdddd56067f20.jpg
# {'content': '谢谢加油，但是我看到试卷那一刻 我觉得是我之前飘了[口罩]', 'likedCount': 0, 'time': 1520731140524, 'nickname': '白安阁', 'avatarurl': 'http://p1.music.126.net/q7ivQN2dMkhtGVlD_oCQ1g==/18744474232433566.jpg', 'avatarpath': 'avatars/56bc6a7ba8c2cfefdebfdddd56067f20.jpg', 'userId': 289993679}
# Records created successfully
# Already Downloaded avatars/56bc6a7ba8c2cfefdebfdddd56067f20.jpg
# avatars/56bc6a7ba8c2cfefdebfdddd56067f20.jpg
# {'content': '同病相怜😁', 'likedCount': 0, 'time': 1520731064232, 'nickname': '白安阁', 'avatarurl': 'http://p1.music.126.net/q7ivQN2dMkhtGVlD_oCQ1g==/18744474232433566.jpg', 'avatarpath': 'avatars/56bc6a7ba8c2cfefdebfdddd56067f20.jpg', 'userId': 289993679}
# Records created successfully
# PAGE :  45
# avatars/a4a1edd5eff7be844b86d748a7b975a0.jpg
# {'content': '加油', 'likedCount': 1, 'time': 1520730267210, 'nickname': '兮年丶丶', 'avatarurl': 'http://p1.music.126.net/TV49zbDWMQiaCgD9jw9BJg==/19154592067953948.jpg', 'avatarpath': 'avatars/a4a1edd5eff7be844b86d748a7b975a0.jpg', 'userId': 118455200}
# Records created successfully
# avatars/bb951872c28b803f0ae8071517da2818.jpg
# {'content': '是啊，火到现在[大哭]', 'likedCount': 0, 'time': 1520729271889, 'nickname': '三曲愁断根', 'avatarurl': 'http://p1.music.126.net/gAH_HCdHqpfp7rJlllVO9g==/109951163188625773.jpg', 'avatarpath': 'avatars/bb951872c28b803f0ae8071517da2818.jpg', 'userId': 592444338}
# Records created successfully
# avatars/259c17d4aeeef714df81ddbe410753a0.jpg
# {'content': '这首歌做了手机铃声三年没换过[幽灵]', 'likedCount': 0, 'time': 1520728043368, 'nickname': '青青小草mm555', 'avatarurl': 'http://p1.music.126.net/We8rG6rJEvLPM1WPG-6G1w==/18640020627744733.jpg', 'avatarpath': 'avatars/259c17d4aeeef714df81ddbe410753a0.jpg', 'userId': 569685523}
# Records created successfully
# avatars/fe53a5b0a2178f839f9a496b654dbd43.jpg
# {'content': '…这位网友，看了你的留言，感觉你对你自己说的佛法是有研究并且相信的。既然习佛法让人心境平和，那你咋还来电音区，听着么让人不平静的音乐', 'likedCount': 1, 'time': 1520728021346, 'nickname': '小贝biubiubiu', 'avatarurl': 'http://p1.music.126.net/KPzXlw3FfUl8RLT137Mctg==/19064432114130066.jpg', 'avatarpath': 'avatars/fe53a5b0a2178f839f9a496b654dbd43.jpg', 'userId': 483066549}
# Records created successfully
# Already Downloaded avatars/f832d0ac2cd00590302f0e8bdbcbd7ec.jpg
# avatars/f832d0ac2cd00590302f0e8bdbcbd7ec.jpg
# {'content': '分享我的歌单，每一首都非常好听，抖腿神曲', 'likedCount': 1, 'time': 1520727456687, 'nickname': '丶梓铭', 'avatarurl': 'http://p1.music.126.net/Rtjx3cWKnBqKQ6-boHJQQw==/109951163176242787.jpg', 'avatarpath': 'avatars/f832d0ac2cd00590302f0e8bdbcbd7ec.jpg', 'userId': 1299121574}
# Records created successfully
# avatars/237c7492f0cceece928d5af6670ee942.jpg
# {'content': '加油[爱心][爱心][爱心][爱心][爱心]', 'likedCount': 1, 'time': 1520726531222, 'nickname': '邵氏天才', 'avatarurl': 'http://p1.music.126.net/YR0WzfkzTUEWdeIFuC952g==/18636722092468138.jpg', 'avatarpath': 'avatars/237c7492f0cceece928d5af6670ee942.jpg', 'userId': 341152985}
# Records created successfully
# avatars/857b27beb6017f58ad37b1e94ba1eb04.jpg
# {'content': '你们结婚了吗？', 'likedCount': 0, 'time': 1520726019020, 'nickname': '美人好香', 'avatarurl': 'http://p1.music.126.net/M-bswNPoEdCMoCxeyrmqpA==/18963277044805998.jpg', 'avatarpath': 'avatars/857b27beb6017f58ad37b1e94ba1eb04.jpg', 'userId': 1339785627}
# Records created successfully
# avatars/0a5709abf6239b1fc709ea87ee14893e.jpg
# {'content': '[口罩]+1', 'likedCount': 0, 'time': 1520725830967, 'nickname': '国产少女', 'avatarurl': 'http://p1.music.126.net/DVt0Sn3k3WqzJu020ktMlQ==/19118308184128062.jpg', 'avatarpath': 'avatars/0a5709abf6239b1fc709ea87ee14893e.jpg', 'userId': 498229370}
# Records created successfully
# Already Downloaded avatars/56bc6a7ba8c2cfefdebfdddd56067f20.jpg
# avatars/56bc6a7ba8c2cfefdebfdddd56067f20.jpg
# {'content': '走在补考的路上，总感觉自己能过[大哭][大哭]', 'likedCount': 5, 'time': 1520725570807, 'nickname': '白安阁', 'avatarurl': 'http://p1.music.126.net/q7ivQN2dMkhtGVlD_oCQ1g==/18744474232433566.jpg', 'avatarpath': 'avatars/56bc6a7ba8c2cfefdebfdddd56067f20.jpg', 'userId': 289993679}
# Records created successfully
# avatars/c7dbfb1c3975e4438ce1cb580ee88ac4.jpg
# {'content': '终其一生不知所属', 'likedCount': 1, 'time': 1520725454713, 'nickname': '原始木头人', 'avatarurl': 'http://p1.music.126.net/hkh1ee-DKnhvJr_6R03-9w==/109951163132844469.jpg', 'avatarpath': 'avatars/c7dbfb1c3975e4438ce1cb580ee88ac4.jpg', 'userId': 1313375279}
# Records created successfully
# avatars/6e6e95945cb9904495dcc6070976d1ba.jpg
# {'content': '我有一个死党，一起念了两年书，他走了，去了韩国，过去的就过去了\n致——小虎', 'likedCount': 1, 'time': 1520725437252, 'nickname': '小兔蹦蹦擦', 'avatarurl': 'http://p1.music.126.net/RNcFHWjJlN433cA1nnwc9w==/109951163182728250.jpg', 'avatarpath': 'avatars/6e6e95945cb9904495dcc6070976d1ba.jpg', 'userId': 1286074497}
# Records created successfully
# Already Downloaded avatars/5d7bbba0cd5ae48cfb0dc1380efdd982.jpg
# avatars/5d7bbba0cd5ae48cfb0dc1380efdd982.jpg
# {'content': '加油', 'likedCount': 1, 'time': 1520725031123, 'nickname': 'Motthew夏思雨', 'avatarurl': 'http://p1.music.126.net/KqZ888YHBU9qOMtClXJT1w==/109951163183391864.jpg', 'avatarpath': 'avatars/5d7bbba0cd5ae48cfb0dc1380efdd982.jpg', 'userId': 1395204820}
# Records created successfully
# Already Downloaded avatars/5d7bbba0cd5ae48cfb0dc1380efdd982.jpg
# avatars/5d7bbba0cd5ae48cfb0dc1380efdd982.jpg
# {'content': '心酸', 'likedCount': 1, 'time': 1520725018579, 'nickname': 'Motthew夏思雨', 'avatarurl': 'http://p1.music.126.net/KqZ888YHBU9qOMtClXJT1w==/109951163183391864.jpg', 'avatarpath': 'avatars/5d7bbba0cd5ae48cfb0dc1380efdd982.jpg', 'userId': 1395204820}
# Records created successfully
# avatars/011e1076b54ca8c148197050532edf75.jpg
# {'content': '那你很幸运', 'likedCount': 0, 'time': 1520724965696, 'nickname': '喰種音樂', 'avatarurl': 'http://p1.music.126.net/6-OJWgAPGfRLYPpwz6djGw==/109951163188792687.jpg', 'avatarpath': 'avatars/011e1076b54ca8c148197050532edf75.jpg', 'userId': 314148971}
# Records created successfully
# avatars/ec7981038e79cd6903770927f31e008e.jpg
# {'content': '对不起', 'likedCount': 0, 'time': 1520724938691, 'nickname': 'CFerGO', 'avatarurl': 'http://p1.music.126.net/VJmqip3iJ9s2LqmHuXAl5g==/109951163191953046.jpg', 'avatarpath': 'avatars/ec7981038e79cd6903770927f31e008e.jpg', 'userId': 1307953951}
# Records created successfully
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# {'content': '好好学学佛法吧，每个众生所感受的所有的痛苦都是往昔的罪业感召的，所有的快乐都是福德感召的。知道这个道理之后要好好的做两件事：第一忏悔以前所做的所有的坏事，起的每一个不善心。第二好好的去积德行善，坚持下去，用不了多久情况就会有所转变了，因为你的心变了，你的世界就变了。', 'likedCount': 2, 'time': 1520724685469, 'nickname': '大光明心', 'avatarurl': 'http://p1.music.126.net/VnZiScyynLG7atLIZ2YPkw==/18686200114669622.jpg', 'avatarpath': 'avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg', 'userId': 1389761529}
# Records created successfully
# avatars/d21f8aa10c1660d20eb83318b9a0f283.jpg
# {'content': '别以你的价值观评判别人认为正确的事。', 'likedCount': 0, 'time': 1520723928050, 'nickname': '叶馨馨馨馨馨馨', 'avatarurl': 'http://p1.music.126.net/fXL63clv8gZx8erBTKmWfQ==/109951163182094262.jpg', 'avatarpath': 'avatars/d21f8aa10c1660d20eb83318b9a0f283.jpg', 'userId': 380058218}
# Records created successfully
# avatars/735049a5c18e34e61b444e1282b0b13f.jpg
# {'content': '我觉得不值，在网上都不要钱', 'likedCount': 1, 'time': 1520723198336, 'nickname': '烦人的村民咘噗嘟', 'avatarurl': 'http://p1.music.126.net/xaOPfxL89pFBfKj6lbv9hA==/18637821604473088.jpg', 'avatarpath': 'avatars/735049a5c18e34e61b444e1282b0b13f.jpg', 'userId': 434700249}
# Records created successfully
# avatars/b9e9557026c8b88b4658cee0976314fb.jpg
# {'content': '第一次听这歌，我循环了三天', 'likedCount': 1, 'time': 1520708993515, 'nickname': '烟雨ti', 'avatarurl': 'http://p1.music.126.net/UIuTVh-GlO8MWlnREj336w==/19151293533068496.jpg', 'avatarpath': 'avatars/b9e9557026c8b88b4658cee0976314fb.jpg', 'userId': 512234991}
# Records created successfully
# avatars/42ea92b50342c0f91c646b43a10cee4e.jpg
# {'content': '说不清，道不明的感觉。很怪异。', 'likedCount': 2, 'time': 1520705326588, 'nickname': '越浅川', 'avatarurl': 'http://p1.music.126.net/5DEHA-YUEnt0fdzhXnAtKQ==/109951163185352023.jpg', 'avatarpath': 'avatars/42ea92b50342c0f91c646b43a10cee4e.jpg', 'userId': 372582841}
# Records created successfully
# PAGE :  46
# avatars/5045b0c676b982880cde157a98d2c2dc.jpg
# {'content': '火成土嗨还行  球球你去百度一下土嗨是什么意思吧', 'likedCount': 2, 'time': 1520703524199, 'nickname': '想个名字烦死人', 'avatarurl': 'http://p1.music.126.net/kyWdfEzjL-dYM7rvRqCPkQ==/18710389371513057.jpg', 'avatarpath': 'avatars/5045b0c676b982880cde157a98d2c2dc.jpg', 'userId': 129689704}
# Records created successfully
# avatars/40f707a7ecf4d71395bb11e93002595d.jpg
# {'content': '你是辗转 你是反则', 'likedCount': 0, 'time': 1520701764749, 'nickname': '季节悻', 'avatarurl': 'http://p1.music.126.net/GdVYBMLMKqp-kef1-ihHQQ==/109951163174946555.jpg', 'avatarpath': 'avatars/40f707a7ecf4d71395bb11e93002595d.jpg', 'userId': 402103099}
# Records created successfully
# avatars/207b8c5e0963c28205b64dea3262134f.jpg
# {'content': '等着看别人喷你', 'likedCount': 0, 'time': 1520700220773, 'nickname': '夜南浅', 'avatarurl': 'http://p1.music.126.net/Z-ghW_e-PHgT9I_WXxNxLA==/19171084742382538.jpg', 'avatarpath': 'avatars/207b8c5e0963c28205b64dea3262134f.jpg', 'userId': 354882728}
# Records created successfully
# avatars/b8ed481fd0867277e558a4b91223297d.jpg
# {'content': '生活好迷茫，曾经挂过驾考，幸好寒假考了出来，然后又碰上教师资格证出成绩，挂了，不知道为什么感觉从未被眷顾，新学期开始准备考研，感觉自己的进度总得慢的要命，明天还要去实验室讲东西，自己其实也不是很懂原理，又和他吵架了，开学这一周总是很尴尬的在一起，不知道现在是什么坚持着生活想回家了', 'likedCount': 2, 'time': 1520698469655, 'nickname': 'Feng轻微凉', 'avatarurl': 'http://p1.music.126.net/juE33VbXm3rJWdPHyTa3GQ==/109951163133387775.jpg', 'avatarpath': 'avatars/b8ed481fd0867277e558a4b91223297d.jpg', 'userId': 415407112}
# Records created successfully
# avatars/1d62a82d68f45c2c134eb26154235910.jpg
# {'content': '卧槽，135翻车了。。。', 'likedCount': 1, 'time': 1520696277691, 'nickname': 'm沉生', 'avatarurl': 'http://p1.music.126.net/ls9Rtgp7WFufu9Hs0-j_zQ==/18800549325249430.jpg', 'avatarpath': 'avatars/1d62a82d68f45c2c134eb26154235910.jpg', 'userId': 384309516}
# Records created successfully
# avatars/182857d8049a4e38877856c81d69e65a.jpg
# {'content': '想念16年还在部队的时候跑步最喜欢这首歌。就是不知道歌名（部队不让用手机，自己偷偷买低音炮，买个内存卡，外出的时候让人乱下几首歌）。现在听了，好激动，好怀念。想去跑个五公里。', 'likedCount': 3, 'time': 1520695329362, 'nickname': 'Aiweller', 'avatarurl': 'http://p1.music.126.net/MWkpDB-rrhY0M-K_JI7AdQ==/18558656767283815.jpg', 'avatarpath': 'avatars/182857d8049a4e38877856c81d69e65a.jpg', 'userId': 601327884}
# Records created successfully
# avatars/67a270ad023033d270c9eaefd20bdd05.jpg
# {'content': '哈哈', 'likedCount': 1, 'time': 1520694568883, 'nickname': '威风堂堂的装13菌', 'avatarurl': 'http://p1.music.126.net/Pz8xwzR0J0pATEWcHChC9w==/18774161046451723.jpg', 'avatarpath': 'avatars/67a270ad023033d270c9eaefd20bdd05.jpg', 'userId': 440632804}
# Records created successfully
# Already Downloaded avatars/67a270ad023033d270c9eaefd20bdd05.jpg
# avatars/67a270ad023033d270c9eaefd20bdd05.jpg
# {'content': '嘿嘿嘿哈哈', 'likedCount': 1, 'time': 1520694454698, 'nickname': '威风堂堂的装13菌', 'avatarurl': 'http://p1.music.126.net/Pz8xwzR0J0pATEWcHChC9w==/18774161046451723.jpg', 'avatarpath': 'avatars/67a270ad023033d270c9eaefd20bdd05.jpg', 'userId': 440632804}
# Records created successfully
# Already Downloaded avatars/67a270ad023033d270c9eaefd20bdd05.jpg
# avatars/67a270ad023033d270c9eaefd20bdd05.jpg
# {'content': '哈哈哈', 'likedCount': 3, 'time': 1520694272157, 'nickname': '威风堂堂的装13菌', 'avatarurl': 'http://p1.music.126.net/Pz8xwzR0J0pATEWcHChC9w==/18774161046451723.jpg', 'avatarpath': 'avatars/67a270ad023033d270c9eaefd20bdd05.jpg', 'userId': 440632804}
# Records created successfully
# Already Downloaded avatars/67a270ad023033d270c9eaefd20bdd05.jpg
# avatars/67a270ad023033d270c9eaefd20bdd05.jpg
# {'content': '哇666666666666666', 'likedCount': 1, 'time': 1520694236526, 'nickname': '威风堂堂的装13菌', 'avatarurl': 'http://p1.music.126.net/Pz8xwzR0J0pATEWcHChC9w==/18774161046451723.jpg', 'avatarpath': 'avatars/67a270ad023033d270c9eaefd20bdd05.jpg', 'userId': 440632804}
# Records created successfully
# avatars/fc9d039d14ef97b5b65d15425c3df784.jpg
# {'content': '进不得，退不得，十年之后看谁活得更潇洒', 'likedCount': 0, 'time': 1520693938285, 'nickname': '-人比心凉', 'avatarurl': 'http://p1.music.126.net/nC1Vk7QANVfqTwNryEDM5g==/1384285147878114.jpg', 'avatarpath': 'avatars/fc9d039d14ef97b5b65d15425c3df784.jpg', 'userId': 272242118}
# Records created successfully
# avatars/20cc30d2f8d8989936e65ac12e7fbd4f.jpg
# {'content': '谢谢，我会一直等他，也祝你如愿以偿，找到属于自己的幸福！', 'likedCount': 0, 'time': 1520692431360, 'nickname': '碧兰如梦icey', 'avatarurl': 'http://p1.music.126.net/YLtJKxP6oX5ooupeGeMXcA==/109951163145388310.jpg', 'avatarpath': 'avatars/20cc30d2f8d8989936e65ac12e7fbd4f.jpg', 'userId': 1370791915}
# Records created successfully
# Already Downloaded avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# avatars/d1644ea89d31c9936f20efb90cb0a09d.jpg
# ...
# {'content': '第一首接触的电音就是faded，很感谢，我对音乐还有感觉的时候爱上了电音[爱心]', 'likedCount': 1, 'time': 1519345661708, 'nickname': '故与野心', 'avatarurl': 'http://p1.music.126.net/gWtj86HmPiU8tU1AyOfMow==/19049038951701021.jpg', 'avatarpath': 'avatars/2d03b28f01955691310b0e6bc62910e8.jpg', 'userId': 1306043503}
# Records created successfully
# avatars/c67551d6f508e53cb668d6df26058515.jpg
# {'content': '同感[流泪]', 'likedCount': 1, 'time': 1519344850043, 'nickname': '_君戰日天', 'avatarurl': 'http://p1.music.126.net/BRL9rA72PSWD6Rg3vDthWg==/18902803905181124.jpg', 'avatarpath': 'avatars/c67551d6f508e53cb668d6df26058515.jpg', 'userId': 1294994954}
# Records created successfully
# avatars/1d2a62c5e7e168c58e2a2c7b2886dde5.jpg
# {'content': '人生不如意事常八九 为了那一二也要好好生活下去', 'likedCount': 1, 'time': 1519341583972, 'nickname': '陳妍同學V', 'avatarurl': 'http://p1.music.126.net/L44RBLNM-lzxfr1PUnB0-Q==/109951162963180601.jpg', 'avatarpath': 'avatars/1d2a62c5e7e168c58e2a2c7b2886dde5.jpg', 'userId': 94306074}
# Records created successfully
# avatars/611a719451ca59845238227ea4cefd0f.jpg
# {'content': '每次去跑步，点开这这首歌。感觉奥特曼的使命降在了自己的身上，贼带劲。', 'likedCount': 2, 'time': 1519339025847, 'nickname': '海口171106', 'avatarurl': 'http://p1.music.126.net/gUd-mIqSinF0HqMyQREEYw==/19204070091170690.jpg', 'avatarpath': 'avatars/611a719451ca59845238227ea4cefd0f.jpg', 'userId': 640900819}
# Records created successfully
# avatars/4a62096953e8023e9acd519ada004e25.jpg
# {'content': '就是听了这首歌才爱上了电音', 'likedCount': 0, 'time': 1519331381949, 'nickname': '卍Eric', 'avatarurl': 'http://p1.music.126.net/d6OaR-ZHuQSt4uNAqEr3gQ==/19036944323841448.jpg', 'avatarpath': 'avatars/4a62096953e8023e9acd519ada004e25.jpg', 'userId': 1301128420}
# Records created successfully
# avatars/d31352eaa7bfad82f3e586faa8fae03a.jpg
# {'content': '快闭嘴吧你，不说没人当你哑了。我现在眼睛就好疼', 'likedCount': 0, 'time': 1519328287937, 'nickname': '医生快让开这个病人我能治', 'avatarurl': 'http://p1.music.126.net/iGbpzzhCuLj0KndKiLPoHg==/109951163160070106.jpg', 'avatarpath': 'avatars/d31352eaa7bfad82f3e586faa8fae03a.jpg', 'userId': 1364499897}
# Records created successfully
# Already Downloaded avatars/d31352eaa7bfad82f3e586faa8fae03a.jpg
# avatars/d31352eaa7bfad82f3e586faa8fae03a.jpg
# {'content': '_(:з」∠)_比我大一岁呢', 'likedCount': 0, 'time': 1519328221133, 'nickname': '医生快让开这个病人我能治', 'avatarurl': 'http://p1.music.126.net/iGbpzzhCuLj0KndKiLPoHg==/109951163160070106.jpg', 'avatarpath': 'avatars/d31352eaa7bfad82f3e586faa8fae03a.jpg', 'userId': 1364499897}
# Records created successfully
# Already Downloaded avatars/5ea67d5406be56fdebe484c53c0678dc.jpg
# avatars/5ea67d5406be56fdebe484c53c0678dc.jpg
# {'content': '给我个理由睡觉好吗', 'likedCount': 2, 'time': 1519325986607, 'nickname': '贪食症绿', 'avatarurl': 'http://p1.music.126.net/OX3PIl-GaxzktbicUh-QrA==/109951163134344546.jpg', 'avatarpath': 'avatars/5ea67d5406be56fdebe484c53c0678dc.jpg', 'userId': 515846773}
# Records created successfully
# avatars/18e7d1d5889c3c471029d48c3bedc247.jpg
# {'content': '我能体会，我爷爷是15年12月24日去的，我听到这个歌的时间也是那一段时间，哭了一晚上，真的', 'likedCount': 2, 'time': 1519323966811, 'nickname': '照影者', 'avatarurl': 'http://p1.music.126.net/-A47WeAEc9ZEDb3rbDf17A==/109951163159414109.jpg', 'avatarpath': 'avatars/18e7d1d5889c3c471029d48c3bedc247.jpg', 'userId': 570896580}
# Records created successfully
# avatars/01301007427eeea92913946202fc520e.jpg
# {'content': 'Faded', 'likedCount': 1, 'time': 1519322583389, 'nickname': 'Antony更', 'avatarurl': 'http://p1.music.126.net/fdRzND48GEdAtG_eslZ0gw==/18522372883457352.jpg', 'avatarpath': 'avatars/01301007427eeea92913946202fc520e.jpg', 'userId': 443647707}
# Records created successfully
# avatars/7aaca14df245c44b6115ce2020bd2be4.jpg
# {'content': '晚安。', 'likedCount': 1, 'time': 1519321093938, 'nickname': 'bcls497', 'avatarurl': 'http://p1.music.126.net/OLaDX73A7EDo3gYLNIwuWA==/109951163189551950.jpg', 'avatarpath': 'avatars/7aaca14df245c44b6115ce2020bd2be4.jpg', 'userId': 588884441}
# Records created successfully
# avatars/32f03c90d50fc75542ca164acbe24456.jpg
# {'content': '在海底', 'likedCount': 1, 'time': 1519321046721, 'nickname': 'BK-历木', 'avatarurl': 'http://p1.music.126.net/16dQu-E4zQ7xHdMc2BVVbA==/109951163159396282.jpg', 'avatarpath': 'avatars/32f03c90d50fc75542ca164acbe24456.jpg', 'userId': 396901023}
# Records created successfully
# avatars/d93c55d6dd770e9e9bd2b5238bc6f014.jpg
# {'content': '前来考古', 'likedCount': 0, 'time': 1519321040347, 'nickname': '沈韵婷', 'avatarurl': 'http://p1.music.126.net/9-5Wq-1a33lqS2xwi4x3ew==/19038043835074308.jpg', 'avatarpath': 'avatars/d93c55d6dd770e9e9bd2b5238bc6f014.jpg', 'userId': 340313463}
# Records created successfully
# Already Downloaded avatars/32f03c90d50fc75542ca164acbe24456.jpg
# avatars/32f03c90d50fc75542ca164acbe24456.jpg
# {'content': '她喜欢这首歌.我。。。', 'likedCount': 0, 'time': 1519321025616, 'nickname': 'BK-历木', 'avatarurl': 'http://p1.music.126.net/16dQu-E4zQ7xHdMc2BVVbA==/109951163159396282.jpg', 'avatarpath': 'avatars/32f03c90d50fc75542ca164acbe24456.jpg', 'userId': 396901023}
# Records created successfully
# avatars/6c7df9726a886479b84ff198a4973002.jpg
# {'content': '有痣青年[强]', 'likedCount': 1, 'time': 1519320450910, 'nickname': 'LARRY123456789', 'avatarurl': 'http://p1.music.126.net/bJQIfoivPAtxPR8n5YdzpQ==/18969874114216838.jpg', 'avatarpath': 'avatars/6c7df9726a886479b84ff198a4973002.jpg', 'userId': 326007302}
# Records created successfully
# avatars/2f40e77113dec85244ad50f72cdc096a.jpg
# {'content': '挺你，加油', 'likedCount': 1, 'time': 1519320294147, 'nickname': 'msajx', 'avatarurl': 'http://p1.music.126.net/B_c19j-CPG7_7pFmCflITQ==/109951163183043560.jpg', 'avatarpath': 'avatars/2f40e77113dec85244ad50f72cdc096a.jpg', 'userId': 618204172}
# Records created successfully
# avatars/8660eed99b7371490fad461fcd778924.jpg
# {'content': '傻瓜，别翻了，手指会累，眼睛会疼。听话，看到我这里就睡吧！我不认识你，但我知道你一定有故事，你好陌生人～晚安❤', 'likedCount': 0, 'time': 1519319811242, 'nickname': '一只小雅a', 'avatarurl': 'http://p1.music.126.net/4liPrMgE1WYC6wNWnAymZg==/18950082904931666.jpg', 'avatarpath': 'avatars/8660eed99b7371490fad461fcd778924.jpg', 'userId': 543464682}
# Records created successfully
# PAGE :  146
# Already Downloaded avatars/8660eed99b7371490fad461fcd778924.jpg
# avatars/8660eed99b7371490fad461fcd778924.jpg
# {'content': '傻瓜，别翻了，手指会累，眼睛会疼。听话，看到我这里就睡吧！我不认识你，但我知道你一定有故事，你好陌生人～晚安❤', 'likedCount': 0, 'time': 1519319811242, 'nickname': '一只小雅a', 'avatarurl': 'http://p1.music.126.net/4liPrMgE1WYC6wNWnAymZg==/18950082904931666.jpg', 'avatarpath': 'avatars/8660eed99b7371490fad461fcd778924.jpg', 'userId': 543464682}
# Records created successfully
# avatars/518035ee1f1d59758429973251c35ebd.jpg
# {'content': '再来重温一下心情', 'likedCount': 1, 'time': 1519318540617, 'nickname': '笠原May和我', 'avatarurl': 'http://p1.music.126.net/7PcIm0NPkOOXjcMILimLCw==/19069929672564859.jpg', 'avatarpath': 'avatars/518035ee1f1d59758429973251c35ebd.jpg', 'userId': 390078716}
# Records created successfully
# avatars/fb1854277db2f8f08bef719ea0629411.jpg
# {'content': '虽然我不认识你们，但我相信你们和我一样默默的翻着评论，怎么想都不知道怎么骗到十个赞', 'likedCount': 3, 'time': 1519318354342, 'nickname': '愿孤独的人不在孤独', 'avatarurl': 'http://p1.music.126.net/G_giBo7jpcBuFtPcMrOA0w==/19056735533161359.jpg', 'avatarpath': 'avatars/fb1854277db2f8f08bef719ea0629411.jpg', 'userId': 476174547}
# Records created successfully
# avatars/74fbd1a94ef48e17467844e5d95a7bb9.jpg
# {'content': '这首歌好刺激', 'likedCount': 0, 'time': 1519318332369, 'nickname': '暗中人1802', 'avatarurl': 'http://p1.music.126.net/QKypEYd94ip_ogZ64nbtSQ==/109951163129466654.jpg', 'avatarpath': 'avatars/74fbd1a94ef48e17467844e5d95a7bb9.jpg', 'userId': 1351446782}
# Records created successfully
# avatars/9256830db99ef07e46a5c5342cda9798.jpg
# {'content': '这一切，早该结束了。\n比如，我怎么又把作业拖到开学前', 'likedCount': 5, 'time': 1519317859404, 'nickname': '百里霜篙', 'avatarurl': 'http://p1.music.126.net/6hjPd6CswEUr4vxXhuHTCA==/109951163143582767.jpg', 'avatarpath': 'avatars/9256830db99ef07e46a5c5342cda9798.jpg', 'userId': 1369618108}
# Records created successfully
# avatars/8ad057866dc2a007af81e7d1e39eef1c.jpg
# {'content': 'Where will you go', 'likedCount': 3, 'time': 1519317727786, 'nickname': 'monica008', 'avatarurl': 'http://p1.music.126.net/GaYCsBH-OqJFTFQZTF8yTQ==/18561955301839609.jpg', 'avatarpath': 'avatars/8ad057866dc2a007af81e7d1e39eef1c.jpg', 'userId': 342778112}
# Records created successfully
# avatars/e0aa01545aa7608f53a1658a3944e45a.jpg
# {'content': '我不是特意找怼，只是有几句话想说，Alan是很牛逼，半路出家还能做到这样，但是他还太年轻，仍需要历练，所以我希望所有人都能看到他的长处与不足，既不要死揪着不放，也不要过分夸大。', 'likedCount': 8, 'time': 1519315954714, 'nickname': '缅岚', 'avatarurl': 'http://p1.music.126.net/mb6UGVyA-aaWEKrCvbP8yA==/18806046883482836.jpg', 'avatarpath': 'avatars/e0aa01545aa7608f53a1658a3944e45a.jpg', 'userId': 404633676}
# Records created successfully
# avatars/7f99e93fa6f918bc961e573b1d931c52.jpg
# {'content': '哈哈[开心][开心]', 'likedCount': 0, 'time': 1519315691864, 'nickname': '贵族化龙流殇吻痕', 'avatarurl': 'http://p1.music.126.net/kTTxckf2xtwcO_f2j9Nhhw==/18823639069491988.jpg', 'avatarpath': 'avatars/7f99e93fa6f918bc961e573b1d931c52.jpg', 'userId': 553970553}
# Records created successfully
# avatars/e13b0fc2cbb1fb26412b6925e202f740.jpg
# {'content': '我胸无大志只想下次期末考进全班前六，这个夏天要努力。', 'likedCount': 0, 'time': 1519315544756, 'nickname': '谢谢你了小兄弟', 'avatarurl': 'http://p1.music.126.net/rZPSDyWven93aIXNgMSMqQ==/109951163101486735.jpg', 'avatarpath': 'avatars/e13b0fc2cbb1fb26412b6925e202f740.jpg', 'userId': 449795689}
# Records created successfully
# avatars/49cf1cb923ea6ea5654e822d18978b7c.jpg
# {'content': '我也是刚听到日推最后一个古风版，又过来温习一遍的[奸笑][奸笑][奸笑]', 'likedCount': 1, 'time': 1519315483077, 'nickname': '糖还是甜的只是人生太苦', 'avatarurl': 'http://p1.music.126.net/-IDUwxqst-BnCWq0AnakUg==/109951163154828016.jpg', 'avatarpath': 'avatars/49cf1cb923ea6ea5654e822d18978b7c.jpg', 'userId': 420702226}
# Records created successfully
# Already Downloaded avatars/49cf1cb923ea6ea5654e822d18978b7c.jpg
# avatars/49cf1cb923ea6ea5654e822d18978b7c.jpg
# {'content': '现在只要两元了[大哭][大哭][大哭]', 'likedCount': 1, 'time': 1519315355204, 'nickname': '糖还是甜的只是人生太苦', 'avatarurl': 'http://p1.music.126.net/-IDUwxqst-BnCWq0AnakUg==/109951163154828016.jpg', 'avatarpath': 'avatars/49cf1cb923ea6ea5654e822d18978b7c.jpg', 'userId': 420702226}
# Records created successfully
# avatars/1e9b8cacea7d84624a64c8ccdebc494d.jpg
# {'content': '不是的，为了你自己，先问问你自己想要什么', 'likedCount': 1, 'time': 1519314701846, 'nickname': 'sealeaf_', 'avatarurl': 'http://p1.music.126.net/ttkDQWzAed39I9VaBnnnaQ==/18685100604292630.jpg', 'avatarpath': 'avatars/1e9b8cacea7d84624a64c8ccdebc494d.jpg', 'userId': 92926786}
# Records created successfully
# Already Downloaded avatars/7f99e93fa6f918bc961e573b1d931c52.jpg
# avatars/7f99e93fa6f918bc961e573b1d931c52.jpg
# {'content': '很久不听了 还是跟以前一样 真他娘的好听', 'likedCount': 3, 'time': 1519314665524, 'nickname': '贵族化龙流殇吻痕', 'avatarurl': 'http://p1.music.126.net/kTTxckf2xtwcO_f2j9Nhhw==/18823639069491988.jpg', 'avatarpath': 'avatars/7f99e93fa6f918bc961e573b1d931c52.jpg', 'userId': 553970553}
# Records created successfully
# avatars/c46c6258bd95d0a321521a572efafebb.jpg
# {'content': 'where  are  you  now                 这么多年了     当时我狠下心不去看你的动态   不去回复你的信息      不去感受你的那份疼。              这时    我是真的想你了    想你当我打开手机时就看见那些亲切的字眼[心碎][心碎]', 'likedCount': 2, 'time': 1519314433107, 'nickname': '藥-檸', 'avatarurl': 'http://p1.music.126.net/AhGVTxp5Ga-qixyqVW8Dhg==/109951163151044398.jpg', 'avatarpath': 'avatars/c46c6258bd95d0a321521a572efafebb.jpg', 'userId': 475397499}
# Records created successfully
# avatars/baa56e73a9df85b16197c31e4e779cca.jpg
# {'content': '因恐惧我们互相不理解，渐渐地我们离彼此越来越远，我的灵魂a你身在何方？丧失你的我犹如丧尸一般，以前的自己啊你身在何方，没有了你我感觉我一天比一天懦弱，越来越不像自己', 'likedCount': 0, 'time': 1519313592070, 'nickname': 'Carmen0511', 'avatarurl': 'http://p1.music.126.net/rJx1Dz-4WoLoSL2XLc6fvQ==/109951163155990774.jpg', 'avatarpath': 'avatars/baa56e73a9df85b16197c31e4e779cca.jpg', 'userId': 130970488}
# Records created successfully
# avatars/f901ccba0bed46ae57ede6c11fd66fba.jpg
# {'content': '现在是2018年2月22日所以说你奋斗了两年 虽然不认识  但还是希望你能够坚持下去  为了梦想能奋斗下去的人永远是最幸运的  加油💪', 'likedCount': 2, 'time': 1519313470907, 'nickname': '_Blessig', 'avatarurl': 'http://p1.music.126.net/mxPCvYsFDtU9BBVeYcf6RQ==/19145795974656164.jpg', 'avatarpath': 'avatars/f901ccba0bed46ae57ede6c11fd66fba.jpg', 'userId': 81001873}
# Records created successfully
# avatars/1c73cbc3df52cada895c2de85409843c.jpg
# {'content': '马上要上学了，只想。。。。给自己加把力，为了前途，为了老师，为了父母。', 'likedCount': 2, 'time': 1519313309586, 'nickname': '苍狼破影', 'avatarurl': 'http://p1.music.126.net/lapi-jR4_wOeN5BA-yKnGw==/109951163159241450.jpg', 'avatarpath': 'avatars/1c73cbc3df52cada895c2de85409843c.jpg', 'userId': 1378589285}
# Records created successfully
# avatars/0d16b37044fd00e7c1ee85a4cf1ba164.jpg
# {'content': '打开这首歌，又仿佛忘记一切烦恼\n', 'likedCount': 1, 'time': 1519311782982, 'nickname': '悟空驾到_', 'avatarurl': 'http://p1.music.126.net/TPGWG2dEpTmMejGwRe9HPQ==/19061133579641928.jpg', 'avatarpath': 'avatars/0d16b37044fd00e7c1ee85a4cf1ba164.jpg', 'userId': 553884734}
# Records created successfully
# avatars/73625ea214a0be8de62267199fd71232.jpg
# {'content': '👍', 'likedCount': 1, 'time': 1519311610732, 'nickname': '三茶茶茶茶', 'avatarurl': 'http://p1.music.126.net/31aw35bK5lJNiQSHLWU9Xg==/109951162936558801.jpg', 'avatarpath': 'avatars/73625ea214a0be8de62267199fd71232.jpg', 'userId': 127408711}
# Records created successfully
# avatars/cb663d346c1ca092e792846030373bf4.jpg
# {'content': '怎么样了？', 'likedCount': 1, 'time': 1519311569097, 'nickname': '虚拟_Xn', 'avatarurl': 'http://p1.music.126.net/oxwUkQKNKpDpzUv2NzWsQg==/109951163177324308.jpg', 'avatarpath': 'avatars/cb663d346c1ca092e792846030373bf4.jpg', 'userId': 604064766}
# Records created successfully
# PAGE :  147
# avatars/9534b83540d7631856b54f1f16509c50.jpg
# {'content': '加油陌生人', 'likedCount': 0, 'time': 1519311075409, 'nickname': '贝霓君', 'avatarurl': 'http://p1.music.126.net/q_nElllS40769nLNGN-zMA==/18887410742261970.jpg', 'avatarpath': 'avatars/9534b83540d7631856b54f1f16509c50.jpg', 'userId': 580916943}
# Records created successfully
# avatars/6f7a73b9eca952608ea8398df4c2bc1a.jpg
# {'content': '曾经遇到一个老神棍 他说“你脾气不好，以后早恋要对女朋友好一点”我不解……后来又遇到一个朋友 才知道老神棍说的是普遍现象.', 'likedCount': 2, 'time': 1519310333889, 'nickname': '淇儿-', 'avatarurl': 'http://p1.music.126.net/XaBLqBzRLTBQWooFkarsmA==/109951163169565055.jpg', 'avatarpath': 'avatars/6f7a73b9eca952608ea8398df4c2bc1a.jpg', 'userId': 1379618856}
# Records created successfully
# Already Downloaded avatars/73174db7f41cdba32f7e0268bedb0a63.jpg
# avatars/73174db7f41cdba32f7e0268bedb0a63.jpg
# {'content': '没有你的多', 'likedCount': 0, 'time': 1519310298884, 'nickname': '666无心', 'avatarurl': 'http://p1.music.126.net/goFjc3ROpSTEffe6JxVEmw==/109951163160542282.jpg', 'avatarpath': 'avatars/73174db7f41cdba32f7e0268bedb0a63.jpg', 'userId': 1296464294}
# Records created successfully
# avatars/c6341440a2fdc5ddf47e7a0da722acd1.jpg
# {'content': '每当听到这首歌我会有一种感觉还会感到彷徨。', 'likedCount': 0, 'time': 1519310269383, 'nickname': 'n无问n', 'avatarurl': 'http://p1.music.126.net/p-8DcW8i_f7dREAw8zRvDQ==/109951163160779836.jpg', 'avatarpath': 'avatars/c6341440a2fdc5ddf47e7a0da722acd1.jpg', 'userId': 1377143066}
# Records created successfully
# avatars/cfe23122225cff8dab5f828ee7d02c9e.jpg
# {'content': '真的很喜欢很喜欢这首歌了 刚刚刷微博 才知道Alan 开通微博了 嘻嘻 🙈', 'likedCount': 0, 'time': 1519310173169, 'nickname': '薄瓷胎', 'avatarurl': 'http://p1.music.126.net/KZvBOjcsWfvusN794fw_jA==/109951163144835795.jpg', 'avatarpath': 'avatars/cfe23122225cff8dab5f828ee7d02c9e.jpg', 'userId': 295181125}
# Records created successfully
# Already Downloaded avatars/73174db7f41cdba32f7e0268bedb0a63.jpg
# avatars/73174db7f41cdba32f7e0268bedb0a63.jpg
# {'content': '工资就像大姨妈：一个月一次，一周左右就没了。工资就像大姨妈：一怀孕就没了。工资就像大姨妈：到了退休年龄，立马没了。工资就像大姨妈：到时间不来就心慌。工资就像大姨妈：从没准时到帐过。工资就像大姨妈：存着觉得涨，流出来的时候又痛。', 'likedCount': 3, 'time': 1519308856359, 'nickname': '666无心', 'avatarurl': 'http://p1.music.126.net/goFjc3ROpSTEffe6JxVEmw==/109951163160542282.jpg', 'avatarpath': 'avatars/73174db7f41cdba32f7e0268bedb0a63.jpg', 'userId': 1296464294}
# Records created successfully
# avatars/c7ebdf8dd7da5743e310c682674c6b33.jpg
# {'content': '有毒', 'likedCount': 2, 'time': 1519307699673, 'nickname': '尬兄弟', 'avatarurl': 'http://p1.music.126.net/JNJaKydbhYhi8jC1bDvTEw==/109951163166606653.jpg', 'avatarpath': 'avatars/c7ebdf8dd7da5743e310c682674c6b33.jpg', 'userId': 334983038}
# Records created successfully

# %% [markdown]
# Finally my spider was detected,but still got enough infomation

# %% [markdown]
# ![](http://oxswstz0r.bkt.clouddn.com/wy010.PNG)

# %%
https://www.zhihu.com/question/36081767
http://pycryptodome.readthedocs.io/en/latest/
https://www.blog.pythonlibrary.org/2016/05/18/python-3-an-intro-to-encryption/
https://stackoverflow.com/questions/47990482/pycryptodome-aes-256-giving-different-output-with-same-key-data
https://github.com/darknessomi/musicbox/wiki/网易云音乐新版WebAPI分析
https://www.ibm.com/developerworks/cn/web/1102_niugang_csrf/#icomments
